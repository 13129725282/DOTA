# %% [markdown]
# ## 删除不要的类别

# %%
import os
import random
import numpy as np
from numpy import *
 
txt_file_path = 'G:/DOTA/train/11/val/lables'  # 原始的标签路径
save_file_path = 'G:/DOTA/train/11/val/new_lables/'  # 修改后的标签路径
 
labels_name = os.listdir(txt_file_path)  # 获得每一个标签名字的列表 / os.listdir() 方法用于返回指定的文件夹包含的文件或文件夹的名字的列表
num = len(labels_name)  # 获取列表长度
list = range(num)  # 创建从0到num的整数列表  list = range(0, num)
files = os.listdir(save_file_path)
 
for i in list:  # 遍历每一个文件
    name = labels_name[i]  # 获取每一个文件的文件名
    read_file = open(txt_file_path + "/" + name, 'r')  # 读取txt_file_path/labels路径中的文件，r表示以只读方式打开文件
    fline = read_file.readlines()  # 读取txt文件中每一行 / readlines()表示读取整行 / fline是列表类型，fline列表里的元素是str类型
    save_txt = open(save_file_path + "/" + name, 'w+')  # 读取save_file_path/labels路径中的文件. w+表示打开一个文件用于读写。如果该文件已存在则打开文件，并从开头开始编辑，即原有内容会被删除。如果该文件不存在，创建新文件。
 
    for j in fline:  # 遍历txt文件中每一行
        list1 = j.split()
        # print(list1)
 
        # 删除类别
        if list1[0] != '0':  # 删除类别1
            if list1[0] != '3':
                if list1[0] != '6':            
                    if list1[0] != '7':  # 删除类别2\
                        if list1[0] != '9':  # 删除类别2                    
                            if list1[0] != '11':
                                if list1[0] != '13':
                                    list2 = list1
                                    #print(list2)

                                    # 修改类别
                                    if list2[0] == '1':
                                        list2[0] = '0'  # 将类别3改成类别1
                                    elif list2[0] == '2':
                                        list2[0] = '1'  # 将类别4改成类别2
                                    elif list2[0] == '4':
                                        list2[0] = '2'  # 将类别5改成类别3
                                    elif list2[0] == '5':
                                        list2[0] = '3'  # 将类别6改成类别4
                                    elif list2[0] == '8':
                                        list2[0] = '4'  # 将类别7改成类别5
                                    elif list2[0] == '10':
                                        list2[0] = '5'  # 将类别7改成类别5
                                    elif list2[0] == '12':
                                        list2[0] = '6'  # 将类别8改成类别6
                                    elif list2[0] == '14':
                                        list2[0] = '7'  # 将类别8改成类别6                                
                                    b = " ".join(list2)   # 将列表转换成字符串类型，且用空格分割
                                    save_txt.write(b)  # 写入新的文件中
                                    save_txt.write('\n')  # 换行
print("finish")
# Out:
# finish

# %%
import os
import random
import numpy as np
from numpy import *
 
txt_file_path = 'G:/DOTA/train/11/train/lables'  # 原始的标签路径
save_file_path = 'G:/DOTA/train/11/train/lables_1'  # 修改后的标签路径
 
labels_name = os.listdir(txt_file_path)  # 获得每一个标签名字的列表 / os.listdir() 方法用于返回指定的文件夹包含的文件或文件夹的名字的列表
num = len(labels_name)  # 获取列表长度
list = range(num)  # 创建从0到num的整数列表  list = range(0, num)
files = os.listdir(save_file_path)
 
for i in list:  # 遍历每一个文件
    name = labels_name[i]  # 获取每一个文件的文件名
    read_file = open(txt_file_path + "/" + name, 'r')  # 读取txt_file_path/labels路径中的文件，r表示以只读方式打开文件
    fline = read_file.readlines()  # 读取txt文件中每一行 / readlines()表示读取整行 / fline是列表类型，fline列表里的元素是str类型
    save_txt = open(save_file_path + "/" + name, 'w+')  # 读取save_file_path/labels路径中的文件. w+表示打开一个文件用于读写。如果该文件已存在则打开文件，并从开头开始编辑，即原有内容会被删除。如果该文件不存在，创建新文件。
 
    for j in fline:  # 遍历txt文件中每一行
        list1 = j.split()
        # print(list1)
 
        # 删除类别
        if list1[0] != '0':  # 删除类别1
            if list1[0] != '1':            
                if list1[0] != '2':  # 删除类别2\
                    if list1[0] != '3':  # 删除类别2                    
                        if list1[0] != '4':
                            if list1[0] != '5':
                                if list1[0] != '6':
                                    if list1[0] != '7':
                                        if list1[0] != '9':
                                            if list1[0] != '11':
                                                if list1[0] != '13':
                                                    list2 = list1
                                                    #print(list2)

                                                    # 修改类别
                                                    if list2[0] == '10':
                                                        list2[0] = '5'  # 将类别3改成类别1
                                                    elif list2[0] == '12':
                                                        list2[0] = '6'  # 将类别4改成类别2
                                                    elif list2[0] == '14':
                                                        list2[0] = '7'  # 将类别5改成类别3
                                                    elif list2[0] == '8':
                                                        list2[0] = '4'  # 将类别5改成类别3

                                                    b = " ".join(list2)   # 将列表转换成字符串类型，且用空格分割
                                                    save_txt.write(b)  # 写入新的文件中
                                                    save_txt.write('\n')  # 换行
print("finish")
# Out:
# finish

# %% [markdown]
# # 裁剪

# %%
import cv2
import os

#  图像宽不足裁剪宽度,填充至裁剪宽度
def fill_right(img, size_w):
    size = img.shape
    #  填充值为数据集均值
    img_fill_right = cv2.copyMakeBorder(img, 0, 0, 0, size_w - size[1], 
                                        cv2.BORDER_CONSTANT, value = (107, 113, 115))
    return img_fill_right

#  图像高不足裁剪高度,填充至裁剪高度
def fill_bottom(img, size_h):
    size = img.shape
    img_fill_bottom = cv2.copyMakeBorder(img, 0, size_h - size[0], 0, 0, 
                                         cv2.BORDER_CONSTANT, value = (107, 113, 115))
    return img_fill_bottom

#  图像宽高不足裁剪宽高度,填充至裁剪宽高度
def fill_right_bottom(img, size_w, size_h):
    size = img.shape
    img_fill_right_bottom = cv2.copyMakeBorder(img, 0, size_h - size[0], 0, size_w - size[1], 
                                               cv2.BORDER_CONSTANT, value = (107, 113, 115))
    return img_fill_right_bottom

#  图像切割
#  img_floder 图像文件夹
#  out_img_floder 图像切割输出文件夹
#  size_w 切割图像宽
#  size_h 切割图像高
#  step 切割步长
def image_split(img_floder, out_img_floder, size_w = 1024, size_h = 1024, step = 250):
    img_list = os.listdir(img_floder)
    count = 0
    for img_name in img_list:
        number = 0
        #  去除.png后缀
        name = img_name[:-4]
        img = cv2.imread(img_floder + "\\" + img_name)
        size = img.shape
        #  若图像宽高大于切割宽高
        if size[0] >= size_h and size[1] >= size_w:
           count = count + 1
           for h in range(0, size[0] - 1, step):
               start_h = h
               for w in range(0, size[1] - 1, step):
                   start_w = w
                   end_h = start_h + size_h
                   if end_h > size[0]:
                      start_h = size[0] - size_h 
                      end_h = start_h + size_h
                   end_w = start_w + size_w
                   if end_w > size[1]:
                      start_w = size[1] - size_w
                   end_w = start_w + size_w
                   cropped = img[start_h : end_h, start_w : end_w]
                   #  用起始坐标来命名切割得到的图像，为的是方便后续标签数据抓取
                   name_img = name + '_'+ str(start_h) +'_' + str(start_w)
                   cv2.imwrite('{}/{}.png'.format(out_img_floder, name_img), cropped)
                   number = number + 1
        #  若图像高大于切割高,但宽小于切割宽
        elif size[0] >= size_h and size[1] < size_w:
            print('图片{}需要在右面补齐'.format(name))
            count = count + 1
            img0 = fill_right(img, size_w)
            for h in range(0, size[0] - 1, step):
               start_h = h
               start_w = 0
               end_h = start_h + size_h
               if end_h > size[0]:
                  start_h = size[0] - size_h 
                  end_h = start_h + size_h
               end_w = start_w + size_w
               cropped = img0[start_h : end_h, start_w : end_w]
               name_img = name + '_' + str(start_h) + '_' + str(start_w)
               cv2.imwrite('{}/{}.png'.format(out_img_floder, name_img), cropped)
               number = number + 1
        #  若图像宽大于切割宽,但高小于切割高
        elif size[0] < size_h and size[1] >= size_w:
            count = count + 1
            print('图片{}需要在下面补齐'.format(name))
            img0 = fill_bottom(img, size_h)
            for w in range(0, size[1] - 1, step):
               start_h = 0
               start_w = w
               end_w = start_w + size_w
               if end_w > size[1]:
                  start_w = size[1] - size_w 
                  end_w = start_w + size_w
               end_h = start_h + size_h
               cropped = img0[start_h : end_h, start_w : end_w]
               name_img = name + '_'+ str(start_h) +'_' + str(start_w)
               cv2.imwrite('{}/{}.png'.format(out_img_floder, name_img), cropped) 
               number = number + 1
        #  若图像宽高小于切割宽高
        elif size[0] < size_h and size[1] < size_w:
            count = count + 1
            print('图片{}需要在下面和右面补齐'.format(name))
            img0 = fill_right_bottom(img,  size_w, size_h)
            cropped = img0[0 : size_h, 0 : size_w]
            name_img = name + '_'+ '0' +'_' + '0'
            cv2.imwrite('{}/{}.png'.format(out_img_floder, name_img), cropped) 
            number = number + 1
        print('{}.png切割成{}张.'.format(name,number))
    print('共完成{}张图片'.format(count))

#  txt切割
#  out_img_floder 图像切割输出文件夹
#  txt_floder txt文件夹
#  out_txt_floder txt切割输出文件夹
#  size_w 切割图像宽
#  size_h 切割图像高
def txt_split(out_img_floder, txt_floder, out_txt_floder, size_h = 1000, size_w = 1000):
    img_list = os.listdir(out_img_floder)
    for img_name in img_list:
        #  去除.png后缀
        name = img_name[:-4]
        #  得到原图像(也即txt)索引 + 切割高 + 切割宽
        name_list = name.split('_')
        txt_name = name_list[0]
        h = int(name_list[1])
        w = int(name_list[2])
        txtpath = txt_floder + "\\" + txt_name + '.txt'
        out_txt_path = out_txt_floder + "\\" + name + '.txt'
        f = open(out_txt_path, 'a')
        #  打开txt文件
        with open(txtpath, 'r') as f_in:   
            lines = f_in.readlines()
            #  逐行读取
            for line  in lines:
                splitline = line.split(' ')
                try:
                    label = splitline[8]
                    difficult = splitline[9]
                    x1 = int(splitline[0])
                    y1 = int(splitline[1])
                    x2 = int(splitline[2])
                    y2 = int(splitline[3])
                    x3 = int(splitline[4])
                    y3 = int(splitline[5])
                    x4 = int(splitline[6])
                    y4 = int(splitline[7])
                    if w <= x1 <= w + size_w and w <= x2 <= w + size_w and \
                    w <= x3 <= w + size_w and w <= x4 <= w + size_w and \
                    h <= y1 <= h + size_h and h <= y2 <= h + size_h and \
                    h <= y3 <= h + size_h and h <= y4 <= h + size_h:
                        f.write('{} {} {} {} {} {} {} {} {} {}'.format(int(x1 - w),
                                int(y1 - h), int(x2 - w), int(y2 - h), int(x3 - w),
                                int(y3 - h), int(x4 - w), int(y4 - h),
                                label, difficult))
                except:
                    continue                
        f.close()
        print('{}.txt切割完成.'.format(name))

#  图像数据集文件夹
img_floder = r'D:\DOTA\val\images'
#  切割得到的图像数据集存放文件夹
out_img_floder = r'D:\DOTA\val\new_images'
#  txt数据集文件夹
txt_floder = r'D:\DOTA\val\labelTxt'
#  切割后数据集的标签文件存放文件夹 
out_txt_floder = r'D:\DOTA\val\new_labelTxt'
#  切割图像宽
size_w = 1024
#  切割图像高
size_h = 1024
#  切割步长,重叠度为size_w - step
step = 250

#image_split(img_floder, out_img_floder, size_w, size_h, step)
txt_split(out_img_floder, txt_floder, out_txt_floder, size_h, size_w)

# %% [markdown]
# # 删除无正样本的数据

# %%
import os

def delete_empty_txt(out_txt_floder, out_img_floder):
    txt_list = os.listdir(out_txt_floder)
    for txt_name in txt_list:
        #  去除.txt后缀
        name = txt_name[:-4]
        #  txt完整路径
        txt_path = out_txt_floder + "\\" + txt_name
        #  对应图像完整路径
        img_path = out_img_floder + "\\" + name + ".jpg"
        with open(txt_path, "r") as f:
            #  读取txt全部内容,然后关闭
            data = f.read()
            f.close()
            #  若该txt为空,删除txt及其对应图像
            if(data == ""):
                os.remove(txt_path)
                os.remove(img_path)
                print('{}为空，已被删除.'.format(name))
  
#切割后数据集的标签文件存放文件夹 
out_txt_floder = r'G:\DOTA\train\11\val\new_lables'
#  切割得到的图像数据集存放文件夹
out_img_floder = r'G:\DOTA\train\11\val\images' 

delete_empty_txt(out_txt_floder, out_img_floder)
# Out:
# P0019_2400_0为空，已被删除.
# P0019_2703_0为空，已被删除.
# P0019_2703_800为空，已被删除.
# P0047_0_0为空，已被删除.
# P0047_0_102为空，已被删除.
# P0060_0_0为空，已被删除.
# P0060_0_1600为空，已被删除.
# P0060_0_2400为空，已被删除.
# P0060_0_2475为空，已被删除.
# P0060_0_800为空，已被删除.
# P0060_1229_0为空，已被删除.
# P0060_1229_1600为空，已被删除.
# P0060_1229_2400为空，已被删除.
# P0060_1229_2475为空，已被删除.
# P0060_1229_800为空，已被删除.
# P0060_800_0为空，已被删除.
# P0060_800_1600为空，已被删除.
# P0060_800_2400为空，已被删除.
# P0060_800_2475为空，已被删除.
# P0060_800_800为空，已被删除.
# P0075_0_0为空，已被删除.
# P0079_0_0为空，已被删除.
# P0081_0_0为空，已被删除.
# P0086_0_0为空，已被删除.
# P0086_0_133为空，已被删除.
# P0086_459_0为空，已被删除.
# P0086_459_133为空，已被删除.
# P0104_0_0为空，已被删除.
# P0104_163_0为空，已被删除.
# P0143_0_0为空，已被删除.
# P0146_800_1600为空，已被删除.
# P0146_800_1667为空，已被删除.
# P0146_860_1600为空，已被删除.
# P0146_860_1667为空，已被删除.
# P0179_1600_1600为空，已被删除.
# P0179_2400_0为空，已被删除.
# P0179_3200_1600为空，已被删除.
# P0179_3518_1600为空，已被删除.
# P0331_1200_0为空，已被删除.
# P0331_800_0为空，已被删除.
# P0347_1600_537为空，已被删除.
# P0347_2396_537为空，已被删除.
# P0665_0_0为空，已被删除.
# P0887_1600_1072为空，已被删除.
# P0887_1740_1072为空，已被删除.
# P1066_800_0为空，已被删除.
# P1179_1600_3200为空，已被删除.
# P1179_1600_4000为空，已被删除.
# P1179_2400_3200为空，已被删除.
# P1184_3200_1570为空，已被删除.
# P1184_4800_0为空，已被删除.
# P1184_4800_800为空，已被删除.
# P1184_5200_0为空，已被删除.
# P1184_5200_800为空，已被删除.
# P1184_800_800为空，已被删除.
# P1210_0_0为空，已被删除.
# P1225_2400_0为空，已被删除.
# P1225_2400_2400为空，已被删除.
# P1225_2976_0为空，已被删除.
# P1225_2976_2400为空，已被删除.
# P1225_800_0为空，已被删除.
# P1230_1600_2400为空，已被删除.
# P1230_1600_3200为空，已被删除.
# P1230_1600_4000为空，已被删除.
# P1230_1600_4176为空，已被删除.
# P1230_2400_0为空，已被删除.
# P1230_2400_3200为空，已被删除.
# P1230_2976_1600为空，已被删除.
# P1230_2976_3200为空，已被删除.
# P1230_2976_800为空，已被删除.
# P1230_800_3200为空，已被删除.
# P1234_1600_0为空，已被删除.
# P1234_2400_800为空，已被删除.
# P1234_2976_1600为空，已被删除.
# P1234_2976_2400为空，已被删除.
# P1234_2976_2976为空，已被删除.
# P1234_2976_800为空，已被删除.
# P1240_0_1600为空，已被删除.
# P1240_0_2400为空，已被删除.
# P1240_1600_0为空，已被删除.
# P1240_1600_1600为空，已被删除.
# P1240_1600_800为空，已被删除.
# P1240_2400_1600为空，已被删除.
# P1240_2400_2400为空，已被删除.
# P1240_2976_2400为空，已被删除.
# P1240_800_0为空，已被删除.
# P1240_800_1600为空，已被删除.
# P1240_800_2400为空，已被删除.
# P1240_800_2976为空，已被删除.
# P1240_800_800为空，已被删除.
# P1242_0_0为空，已被删除.
# P1242_1600_0为空，已被删除.
# P1242_1600_800为空，已被删除.
# P1242_2400_1600为空，已被删除.
# P1242_2400_2400为空，已被删除.
# P1242_2400_2976为空，已被删除.
# P1242_2976_2976为空，已被删除.
# P1242_2976_800为空，已被删除.
# P1246_0_1600为空，已被删除.
# P1246_0_2976为空，已被删除.
# P1246_2400_0为空，已被删除.
# P1246_800_1600为空，已被删除.
# P1257_0_1600为空，已被删除.
# P1257_0_800为空，已被删除.
# P1257_1600_0为空，已被删除.
# P1257_1600_2976为空，已被删除.
# P1257_2400_800为空，已被删除.
# P1266_1600_2976为空，已被删除.
# P1266_2400_1600为空，已被删除.
# P1266_2596_1600为空，已被删除.
# P1266_800_1600为空，已被删除.
# P1266_800_2400为空，已被删除.
# P1266_800_2976为空，已被删除.
# P1268_0_2400为空，已被删除.
# P1268_0_2976为空，已被删除.
# P1268_1600_0为空，已被删除.
# P1268_1600_2976为空，已被删除.
# P1268_2400_0为空，已被删除.
# P1268_2596_0为空，已被删除.
# P1268_800_2400为空，已被删除.
# P1268_800_2976为空，已被删除.
# P1269_0_800为空，已被删除.
# P1269_1600_0为空，已被删除.
# P1269_1600_2400为空，已被删除.
# P1269_1600_2976为空，已被删除.
# P1269_1600_800为空，已被删除.
# P1269_2400_0为空，已被删除.
# P1269_2400_1600为空，已被删除.
# P1269_2400_2400为空，已被删除.
# P1269_2400_800为空，已被删除.
# P1269_2596_1600为空，已被删除.
# P1269_2596_2400为空，已被删除.
# P1269_2596_2976为空，已被删除.
# P1269_2596_800为空，已被删除.
# P1269_800_2400为空，已被删除.
# P1269_800_2976为空，已被删除.
# P1283_0_800为空，已被删除.
# P1314_1600_2976为空，已被删除.
# P1314_2976_1600为空，已被删除.
# P1314_800_2400为空，已被删除.
# P1314_800_2976为空，已被删除.
# P1315_0_1600为空，已被删除.
# P1315_0_2400为空，已被删除.
# P1315_0_2976为空，已被删除.
# P1315_0_800为空，已被删除.
# P1315_1600_0为空，已被删除.
# P1315_1600_1600为空，已被删除.
# P1315_1600_800为空，已被删除.
# P1315_2400_0为空，已被删除.
# P1315_2400_1600为空，已被删除.
# P1315_2400_2400为空，已被删除.
# P1315_2400_2976为空，已被删除.
# P1315_2400_800为空，已被删除.
# P1315_2976_0为空，已被删除.
# P1315_2976_1600为空，已被删除.
# P1315_2976_2400为空，已被删除.
# P1315_2976_2976为空，已被删除.
# P1315_2976_800为空，已被删除.
# P1315_800_0为空，已被删除.
# P1315_800_1600为空，已被删除.
# P1315_800_2400为空，已被删除.
# P1315_800_2976为空，已被删除.
# P1315_800_800为空，已被删除.
# P1323_0_0为空，已被删除.
# P1323_0_2400为空，已被删除.
# P1323_0_2976为空，已被删除.
# P1323_0_800为空，已被删除.
# P1323_1600_0为空，已被删除.
# P1323_1600_1600为空，已被删除.
# P1323_1600_2976为空，已被删除.
# P1323_1600_800为空，已被删除.
# P1323_2400_0为空，已被删除.
# P1323_2400_2976为空，已被删除.
# P1323_2976_0为空，已被删除.
# P1323_2976_1600为空，已被删除.
# P1323_2976_2976为空，已被删除.
# P1323_2976_800为空，已被删除.
# P1323_800_1600为空，已被删除.
# P1323_800_2400为空，已被删除.
# P1323_800_2976为空，已被删除.
# P1323_800_800为空，已被删除.
# P1332_0_2400为空，已被删除.
# P1332_2976_0为空，已被删除.
# P1342_0_0为空，已被删除.
# P1342_0_1600为空，已被删除.
# P1342_0_2400为空，已被删除.
# P1342_0_2976为空，已被删除.
# P1342_0_800为空，已被删除.
# P1342_1600_0为空，已被删除.
# P1342_1600_2400为空，已被删除.
# P1342_2400_0为空，已被删除.
# P1342_2400_1600为空，已被删除.
# P1342_2400_2400为空，已被删除.
# P1342_2400_2976为空，已被删除.
# P1342_2400_800为空，已被删除.
# P1342_2976_0为空，已被删除.
# P1342_2976_1600为空，已被删除.
# P1342_2976_2400为空，已被删除.
# P1342_2976_2976为空，已被删除.
# P1342_2976_800为空，已被删除.
# P1342_800_2400为空，已被删除.
# P1342_800_800为空，已被删除.
# P1356_0_1600为空，已被删除.
# P1356_0_2400为空，已被删除.
# P1356_0_2976为空，已被删除.
# P1356_1600_1600为空，已被删除.
# P1356_1600_2400为空，已被删除.
# P1356_1600_2976为空，已被删除.
# P1356_1600_800为空，已被删除.
# P1356_2400_0为空，已被删除.
# P1356_2400_1600为空，已被删除.
# P1356_2400_2400为空，已被删除.
# P1356_2400_2976为空，已被删除.
# P1356_2976_0为空，已被删除.
# P1356_2976_1600为空，已被删除.
# P1356_2976_2400为空，已被删除.
# P1356_2976_2976为空，已被删除.
# P1356_800_1600为空，已被删除.
# P1356_800_2400为空，已被删除.
# P1356_800_2976为空，已被删除.
# P1370_0_2400为空，已被删除.
# P1370_0_2976为空，已被删除.
# P1370_800_1600为空，已被删除.
# P1370_800_2400为空，已被删除.
# P1370_800_2976为空，已被删除.
# P1371_2976_0为空，已被删除.
# P1373_0_2400为空，已被删除.
# P1373_2976_2400为空，已被删除.
# P1373_2976_2976为空，已被删除.
# P1377_0_0为空，已被删除.
# P1377_1600_2400为空，已被删除.
# P1377_1600_2770为空，已被删除.
# P1377_2400_1600为空，已被删除.
# P1377_2400_2400为空，已被删除.
# P1377_2400_2770为空，已被删除.
# P1377_2992_1600为空，已被删除.
# P1377_2992_2400为空，已被删除.
# P1377_2992_2770为空，已被删除.
# P1380_0_1600为空，已被删除.
# P1380_0_2400为空，已被删除.
# P1380_0_800为空，已被删除.
# P1380_1600_0为空，已被删除.
# P1380_1600_1600为空，已被删除.
# P1380_1600_2400为空，已被删除.
# P1380_1600_3200为空，已被删除.
# P1380_1600_3373为空，已被删除.
# P1380_2400_0为空，已被删除.
# P1380_2400_1600为空，已被删除.
# P1380_2400_3373为空，已被删除.
# P1380_2400_800为空，已被删除.
# P1380_3200_0为空，已被删除.
# P1380_3200_3200为空，已被删除.
# P1380_3200_3373为空，已被删除.
# P1380_3200_800为空，已被删除.
# P1380_3670_0为空，已被删除.
# P1380_3670_3200为空，已被删除.
# P1380_3670_3373为空，已被删除.
# P1380_3670_800为空，已被删除.
# P1380_800_0为空，已被删除.
# P1380_800_800为空，已被删除.
# P1384_0_0为空，已被删除.
# P1384_0_1600为空，已被删除.
# P1384_0_2400为空，已被删除.
# P1384_0_4800为空，已被删除.
# P1384_1600_0为空，已被删除.
# P1384_1600_3200为空，已被删除.
# P1384_1600_4000为空，已被删除.
# P1384_1600_4800为空，已被删除.
# P1384_1600_4840为空，已被删除.
# P1384_2400_0为空，已被删除.
# P1384_2400_3200为空，已被删除.
# P1384_2400_4000为空，已被删除.
# P1384_2400_4800为空，已被删除.
# P1384_2400_4840为空，已被删除.
# P1384_2400_800为空，已被删除.
# P1384_3200_1600为空，已被删除.
# P1384_3200_4800为空，已被删除.
# P1384_3200_4840为空，已被删除.
# P1384_3200_800为空，已被删除.
# P1384_4000_1600为空，已被删除.
# P1384_4000_800为空，已被删除.
# P1384_4611_0为空，已被删除.
# P1384_4611_1600为空，已被删除.
# P1384_4611_2400为空，已被删除.
# P1384_4611_4800为空，已被删除.
# P1384_4611_4840为空，已被删除.
# P1384_4611_800为空，已被删除.
# P1384_800_0为空，已被删除.
# P1384_800_3200为空，已被删除.
# P1384_800_4000为空，已被删除.
# P1384_800_4800为空，已被删除.
# P1384_800_4840为空，已被删除.
# P1410_0_800为空，已被删除.
# P1410_1600_3200为空，已被删除.
# P1410_1600_4000为空，已被删除.
# P1410_1600_4312为空，已被删除.
# P1410_1600_800为空，已被删除.
# P1410_2400_0为空，已被删除.
# P1410_2400_4000为空，已被删除.
# P1410_2400_4312为空，已被删除.
# P1410_2400_800为空，已被删除.
# P1410_3200_0为空，已被删除.
# P1410_3200_3200为空，已被删除.
# P1410_4000_0为空，已被删除.
# P1410_4000_2400为空，已被删除.
# P1456_800_2400为空，已被删除.
# P1456_800_2470为空，已被删除.
# P1471_800_1600为空，已被删除.
# P1513_0_1600为空，已被删除.
# P1513_0_1628为空，已被删除.
# P1513_2400_1600为空，已被删除.
# P1513_2400_1628为空，已被删除.
# P1513_800_1600为空，已被删除.
# P1513_800_1628为空，已被删除.
# P1513_800_800为空，已被删除.
# P1518_1600_0为空，已被删除.
# P1518_2400_2976为空，已被删除.
# P1529_1600_0为空，已被删除.
# P1541_1600_1600为空，已被删除.
# P1541_1600_2400为空，已被删除.
# P1541_1600_2976为空，已被删除.
# P1541_2400_1600为空，已被删除.
# P1541_800_2400为空，已被删除.
# P1541_800_2976为空，已被删除.
# P1542_2400_1600为空，已被删除.
# P1547_0_800为空，已被删除.
# P1547_2400_800为空，已被删除.
# P1557_1600_1600为空，已被删除.
# P1557_1600_2400为空，已被删除.
# P1557_1600_2976为空，已被删除.
# P1560_0_0为空，已被删除.
# P1560_2976_2976为空，已被删除.
# P1560_800_0为空，已被删除.
# P1561_2400_2400为空，已被删除.
# P1561_2976_0为空，已被删除.
# P1561_2976_2400为空，已被删除.
# P1561_2976_800为空，已被删除.
# P1566_2400_1600为空，已被删除.
# P1566_2400_800为空，已被删除.
# P1566_2976_1600为空，已被删除.
# P1566_2976_800为空，已被删除.
# P1569_1600_3200为空，已被删除.
# P1569_1600_3270为空，已被删除.
# P1570_0_1600为空，已被删除.
# P1570_1600_2976为空，已被删除.
# P1570_2400_2976为空，已被删除.
# P1570_800_2400为空，已被删除.
# P1579_1600_2976为空，已被删除.
# P1579_2400_800为空，已被删除.
# P1579_2976_1600为空，已被删除.
# P1579_2976_800为空，已被删除.
# P1581_0_1600为空，已被删除.
# P1581_0_800为空，已被删除.
# P1581_1600_800为空，已被删除.
# P1581_2400_0为空，已被删除.
# P1581_2976_0为空，已被删除.
# P1581_2976_800为空，已被删除.
# P1581_800_1600为空，已被删除.
# P1581_800_800为空，已被删除.
# P1584_0_3200为空，已被删除.
# P1584_0_3268为空，已被删除.
# P1584_1600_3200为空，已被删除.
# P1584_1600_3268为空，已被删除.
# P1584_2400_3200为空，已被删除.
# P1584_2400_3268为空，已被删除.
# P1586_0_0为空，已被删除.
# P1586_1600_2976为空，已被删除.
# P1586_2400_0为空，已被删除.
# P1586_2976_0为空，已被删除.
# P1586_800_0为空，已被删除.
# P1586_800_1600为空，已被删除.
# P1586_800_800为空，已被删除.
# P1596_1600_0为空，已被删除.
# P1596_2400_0为空，已被删除.
# P1598_1600_1600为空，已被删除.
# P1598_1600_2400为空，已被删除.
# P1598_1600_800为空，已被删除.
# P1598_2400_0为空，已被删除.
# P1598_2400_1600为空，已被删除.
# P1598_2400_2400为空，已被删除.
# P1598_2400_2976为空，已被删除.
# P1598_2400_800为空，已被删除.
# P1598_3200_1600为空，已被删除.
# P1598_3954_1600为空，已被删除.
# P1598_3954_800为空，已被删除.
# P1598_800_2400为空，已被删除.
# P1601_800_1600为空，已被删除.
# P1601_800_2400为空，已被删除.
# P1601_800_2976为空，已被删除.
# P1610_0_0为空，已被删除.
# P1610_0_1600为空，已被删除.
# P1610_0_2400为空，已被删除.
# P1610_0_2976为空，已被删除.
# P1610_0_800为空，已被删除.
# P1610_1600_1600为空，已被删除.
# P1610_2400_1600为空，已被删除.
# P1610_800_2400为空，已被删除.
# P1610_800_2976为空，已被删除.
# P1619_1600_1600为空，已被删除.
# P1619_1600_2400为空，已被删除.
# P1619_1600_2976为空，已被删除.
# P1619_2400_1600为空，已被删除.
# P1619_2400_2400为空，已被删除.
# P1619_2976_1600为空，已被删除.
# P1619_2976_800为空，已被删除.
# P1619_800_2400为空，已被删除.
# P1619_800_2976为空，已被删除.
# P1623_0_0为空，已被删除.
# P1623_3200_1600为空，已被删除.
# P1643_1600_800为空，已被删除.
# P1643_2400_800为空，已被删除.
# P1643_2976_1600为空，已被删除.
# P1647_0_2400为空，已被删除.
# P1647_0_2976为空，已被删除.
# P1647_1600_0为空，已被删除.
# P1647_1600_800为空，已被删除.
# P1647_2400_0为空，已被删除.
# P1647_2400_800为空，已被删除.
# P1647_2976_800为空，已被删除.
# P1647_800_0为空，已被删除.
# P1651_0_1600为空，已被删除.
# P1651_0_2400为空，已被删除.
# P1651_0_800为空，已被删除.
# P1651_1600_1600为空，已被删除.
# P1651_1600_2400为空，已被删除.
# P1651_2400_2976为空，已被删除.
# P1651_2976_2976为空，已被删除.
# P1651_800_1600为空，已被删除.
# P1651_800_2400为空，已被删除.
# P1666_0_0为空，已被删除.
# P1666_0_800为空，已被删除.
# P1666_2400_0为空，已被删除.
# P1666_2400_2400为空，已被删除.
# P1666_2976_2400为空，已被删除.
# P1666_800_800为空，已被删除.
# P1672_0_0为空，已被删除.
# P1672_0_800为空，已被删除.
# P1672_1600_2400为空，已被删除.
# P1672_1600_2976为空，已被删除.
# P1672_800_1600为空，已被删除.
# P1672_800_2400为空，已被删除.
# P1672_800_2976为空，已被删除.
# P1679_2400_0为空，已被删除.
# P1679_3962_0为空，已被删除.
# P1693_0_2400为空，已被删除.
# P1693_0_2976为空，已被删除.
# P1693_1600_1600为空，已被删除.
# P1693_1600_2400为空，已被删除.
# P1693_800_2400为空，已被删除.
# P1699_0_0为空，已被删除.
# P1699_800_0为空，已被删除.
# P1700_0_1600为空，已被删除.
# P1700_0_2400为空，已被删除.
# P1700_0_2976为空，已被删除.
# P1700_2400_2400为空，已被删除.
# P1700_2400_2976为空，已被删除.
# P1700_2976_0为空，已被删除.
# P1700_2976_1600为空，已被删除.
# P1700_2976_2400为空，已被删除.
# P1700_2976_2976为空，已被删除.
# P1700_800_0为空，已被删除.
# P1700_800_2400为空，已被删除.
# P1713_2400_800为空，已被删除.
# P1713_2976_0为空，已被删除.
# P1713_2976_800为空，已被删除.
# P1720_1600_800为空，已被删除.
# P1720_2400_800为空，已被删除.
# P1720_800_2400为空，已被删除.
# P1742_800_2400为空，已被删除.
# P1749_0_0为空，已被删除.
# P1749_2400_1600为空，已被删除.
# P1749_2976_1600为空，已被删除.
# P1749_2976_2400为空，已被删除.
# P1749_2976_2976为空，已被删除.
# P1750_1600_0为空，已被删除.
# P1750_800_0为空，已被删除.
# P1751_0_0为空，已被删除.
# P1751_0_1600为空，已被删除.
# P1751_0_2400为空，已被删除.
# P1751_0_2976为空，已被删除.
# P1751_0_800为空，已被删除.
# P1751_1600_0为空，已被删除.
# P1751_1600_2400为空，已被删除.
# P1751_1600_2976为空，已被删除.
# P1751_1600_800为空，已被删除.
# P1751_2400_2400为空，已被删除.
# P1751_2976_0为空，已被删除.
# P1751_800_0为空，已被删除.
# P1751_800_2400为空，已被删除.
# P1751_800_2976为空，已被删除.
# P1752_0_2976为空，已被删除.
# P1752_1600_1600为空，已被删除.
# P1752_1600_2400为空，已被删除.
# P1752_1600_2976为空，已被删除.
# P1752_1600_800为空，已被删除.
# P1752_2400_0为空，已被删除.
# P1752_2400_1600为空，已被删除.
# P1752_2976_2400为空，已被删除.
# P1752_2976_2976为空，已被删除.
# P1752_800_0为空，已被删除.
# P1752_800_2400为空，已被删除.
# P1752_800_2976为空，已被删除.
# P1754_0_0为空，已被删除.
# P1754_0_2400为空，已被删除.
# P1754_0_800为空，已被删除.
# P1754_1600_0为空，已被删除.
# P1754_3921_0为空，已被删除.
# P1754_800_0为空，已被删除.
# P1754_800_1600为空，已被删除.
# P1754_800_2400为空，已被删除.
# P1754_800_2976为空，已被删除.
# P1754_800_800为空，已被删除.
# P1759_2976_2976为空，已被删除.
# P1763_0_1600为空，已被删除.
# P1763_0_800为空，已被删除.
# P1763_1600_800为空，已被删除.
# P1763_2400_800为空，已被删除.
# P1763_2976_800为空，已被删除.
# P1770_1600_800为空，已被删除.
# P1770_2400_800为空，已被删除.
# P1770_3200_1600为空，已被删除.
# P1770_3200_800为空，已被删除.
# P1770_3946_2400为空，已被删除.
# P1770_3946_2976为空，已被删除.
# P1770_3946_800为空，已被删除.
# P1770_800_1600为空，已被删除.
# P1770_800_2400为空，已被删除.
# P1770_800_800为空，已被删除.
# P1809_2400_2400为空，已被删除.
# P1809_2400_4000为空，已被删除.
# P1809_3200_2400为空，已被删除.
# P1809_3200_3200为空，已被删除.
# P1809_4000_3200为空，已被删除.
# P1809_4000_4000为空，已被删除.
# P1809_5600_2400为空，已被删除.
# P1809_5600_3200为空，已被删除.
# P1809_5735_2400为空，已被删除.
# P1809_5735_3200为空，已被删除.
# P1809_800_0为空，已被删除.
# P1854_0_5600为空，已被删除.
# P1854_1600_0为空，已被删除.
# P1854_800_0为空，已被删除.
# P2068_0_0为空，已被删除.
# P2167_0_0为空，已被删除.
# P2167_0_243为空，已被删除.
# P2167_52_0为空，已被删除.
# P2167_52_243为空，已被删除.
# P2169_0_0为空，已被删除.
# P2194_1148_0为空，已被删除.
# P2194_800_0为空，已被删除.
# P2256_0_1600为空，已被删除.
# P2256_0_2400为空，已被删除.
# P2256_0_3200为空，已被删除.
# P2256_0_3570为空，已被删除.
# P2256_506_0为空，已被删除.
# P2256_506_1600为空，已被删除.
# P2256_506_2400为空，已被删除.
# P2256_506_3200为空，已被删除.
# P2256_506_800为空，已被删除.
# P2271_800_2400为空，已被删除.
# P2285_0_2400为空，已被删除.
# P2286_1042_800为空，已被删除.
# P2286_800_1539为空，已被删除.
# P2331_0_0为空，已被删除.
# P2331_800_800为空，已被删除.
# P2337_0_0为空，已被删除.
# P2337_0_1401为空，已被删除.
# P2337_0_800为空，已被删除.
# P2337_1372_0为空，已被删除.
# P2337_800_0为空，已被删除.
# P2337_800_1401为空，已被删除.
# P2337_800_800为空，已被删除.
# P2342_1350_800为空，已被删除.
# P2342_1350_890为空，已被删除.
# P2342_800_800为空，已被删除.
# P2342_800_890为空，已被删除.
# P2351_0_0为空，已被删除.
# P2351_705_0为空，已被删除.
# P2351_705_800为空，已被删除.
# P2351_705_822为空，已被删除.
# P2363_0_0为空，已被删除.
# P2363_800_1213为空，已被删除.
# P2363_893_0为空，已被删除.
# P2363_893_1213为空，已被删除.
# P2363_893_800为空，已被删除.
# P2374_0_0为空，已被删除.
# P2374_686_0为空，已被删除.
# P2375_800_0为空，已被删除.
# P2375_800_541为空，已被删除.
# P2378_0_0为空，已被删除.
# P2378_800_0为空，已被删除.
# P2385_800_1047为空，已被删除.
# P2385_800_800为空，已被删除.
# P2385_984_1047为空，已被删除.
# P2385_984_800为空，已被删除.
# P2394_0_781为空，已被删除.
# P2394_800_0为空，已被删除.
# P2394_800_781为空，已被删除.
# P2394_964_0为空，已被删除.
# P2394_964_781为空，已被删除.
# P2404_0_1600为空，已被删除.
# P2404_0_2400为空，已被删除.
# P2404_0_800为空，已被删除.
# P2404_1600_2400为空，已被删除.
# P2404_2400_3200为空，已被删除.
# P2404_2400_4000为空，已被删除.
# P2404_800_1600为空，已被删除.
# P2404_800_2400为空，已被删除.
# P2408_1539_800为空，已被删除.
# P2408_1539_973为空，已被删除.
# P2413_0_0为空，已被删除.
# P2413_0_1159为空，已被删除.
# P2420_0_0为空，已被删除.
# P2429_1600_0为空，已被删除.
# P2429_1796_0为空，已被删除.
# P2446_0_0为空，已被删除.
# P2446_0_800为空，已被删除.
# P2446_0_991为空，已被删除.
# P2446_1289_800为空，已被删除.
# P2446_1289_991为空，已被删除.
# P2446_800_0为空，已被删除.
# P2446_800_800为空，已被删除.
# P2446_800_991为空，已被删除.
# P2449_0_0为空，已被删除.
# P2450_0_0为空，已被删除.
# P2450_0_656为空，已被删除.
# P2455_0_800为空，已被删除.
# P2455_0_847为空，已被删除.
# P2462_1179_0为空，已被删除.
# P2462_800_0为空，已被删除.
# P2477_0_0为空，已被删除.
# P2477_0_600为空，已被删除.
# P2477_800_0为空，已被删除.
# P2478_0_727为空，已被删除.
# P2478_598_727为空，已被删除.
# P2481_0_1307为空，已被删除.
# P2481_800_1307为空，已被删除.
# P2488_800_1298为空，已被删除.
# P2488_800_800为空，已被删除.
# P2502_0_0为空，已被删除.
# P2502_1400_0为空，已被删除.
# P2504_0_0为空，已被删除.
# P2504_0_596为空，已被删除.
# P2504_1118_0为空，已被删除.
# P2504_1118_596为空，已被删除.
# P2504_800_0为空，已被删除.
# P2504_800_596为空，已被删除.
# P2539_1196_0为空，已被删除.
# P2539_800_0为空，已被删除.
# P2541_0_1590为空，已被删除.
# P2541_1542_0为空，已被删除.
# P2541_1542_800为空，已被删除.
# P2541_800_1590为空，已被删除.
# P2541_800_800为空，已被删除.
# P2542_0_0为空，已被删除.
# P2542_1463_1082为空，已被删除.
# P2542_1463_800为空，已被删除.
# P2542_800_0为空，已被删除.
# P2547_0_0为空，已被删除.
# P2547_0_2704为空，已被删除.
# P2547_1401_0为空，已被删除.
# P2547_1401_800为空，已被删除.
# P2547_800_0为空，已被删除.
# P2547_800_800为空，已被删除.
# P2563_0_0为空，已被删除.
# P2563_145_0为空，已被删除.
# P2570_0_0为空，已被删除.
# P2570_0_775为空，已被删除.
# P2570_441_0为空，已被删除.
# P2570_441_775为空，已被删除.
# P2582_0_0为空，已被删除.
# P2582_0_674为空，已被删除.
# P2587_0_0为空，已被删除.
# P2593_0_0为空，已被删除.
# P2598_0_800为空，已被删除.
# P2608_0_0为空，已被删除.
# P2608_1427_1062为空，已被删除.
# P2610_0_800为空，已被删除.
# P2610_0_814为空，已被删除.
# P2645_800_3581为空，已被删除.
# P2678_0_2400为空，已被删除.
# P2678_0_3200为空，已被删除.
# P2678_0_3201为空，已被删除.
# P2678_800_3200为空，已被删除.
# P2678_800_3201为空，已被删除.
# P2689_0_1600为空，已被删除.
# P2689_0_2400为空，已被删除.
# P2689_0_3200为空，已被删除.
# P2689_0_4000为空，已被删除.
# P2689_0_5134为空，已被删除.
# P2695_0_0为空，已被删除.
# P2695_0_1600为空，已被删除.
# P2695_0_2400为空，已被删除.
# P2695_0_2968为空，已被删除.
# P2695_0_800为空，已被删除.
# P2695_1322_0为空，已被删除.
# P2695_1322_1600为空，已被删除.
# P2695_1322_2400为空，已被删除.
# P2695_1322_800为空，已被删除.
# P2695_800_0为空，已被删除.
# P2695_800_1600为空，已被删除.
# P2695_800_2400为空，已被删除.
# P2695_800_2968为空，已被删除.
# P2695_800_800为空，已被删除.
# P2701_0_0为空，已被删除.
# P2701_1597_0为空，已被删除.
# P2701_1597_1600为空，已被删除.
# P2701_1597_2400为空，已被删除.
# P2701_1597_800为空，已被删除.
# P2701_800_0为空，已被删除.
# P2701_800_1600为空，已被删除.
# P2701_800_800为空，已被删除.
# P2709_0_0为空，已被删除.
# P2709_0_800为空，已被删除.
# P2709_800_0为空，已被删除.
# P2709_800_1600为空，已被删除.
# P2714_0_0为空，已被删除.
# P2714_0_1600为空，已被删除.
# P2714_0_2400为空，已被删除.
# P2714_0_3200为空，已被删除.
# P2714_0_3513为空，已被删除.
# P2714_0_800为空，已被删除.
# P2714_1426_0为空，已被删除.
# P2714_1426_1600为空，已被删除.
# P2714_1426_2400为空，已被删除.
# P2714_1426_3200为空，已被删除.
# P2714_1426_3513为空，已被删除.
# P2714_1426_800为空，已被删除.
# P2714_800_0为空，已被删除.
# P2714_800_1600为空，已被删除.
# P2714_800_2400为空，已被删除.
# P2714_800_3200为空，已被删除.
# P2714_800_3513为空，已被删除.
# P2714_800_800为空，已被删除.
# P2718_0_1600为空，已被删除.
# P2718_0_2400为空，已被删除.
# P2718_0_3200为空，已被删除.
# P2718_0_3512为空，已被删除.
# P2718_1422_1600为空，已被删除.
# P2718_1422_800为空，已被删除.
# P2718_800_0为空，已被删除.
# P2718_800_1600为空，已被删除.
# P2718_800_2400为空，已被删除.
# P2718_800_3200为空，已被删除.
# P2718_800_3512为空，已被删除.
# P2718_800_800为空，已被删除.
# P2721_0_0为空，已被删除.
# P2721_0_2400为空，已被删除.
# P2721_0_3200为空，已被删除.
# P2721_0_3515为空，已被删除.
# P2721_1429_0为空，已被删除.
# P2721_1429_1600为空，已被删除.
# P2721_1429_2400为空，已被删除.
# P2721_1429_3200为空，已被删除.
# P2721_1429_3515为空，已被删除.
# P2721_1429_800为空，已被删除.
# P2721_800_0为空，已被删除.
# P2721_800_1600为空，已被删除.
# P2721_800_2400为空，已被删除.
# P2721_800_3200为空，已被删除.
# P2721_800_3515为空，已被删除.
# P2721_800_800为空，已被删除.
# P2722_0_1600为空，已被删除.
# P2722_0_2400为空，已被删除.
# P2722_0_800为空，已被删除.
# P2722_1422_0为空，已被删除.
# P2722_1422_1600为空，已被删除.
# P2722_1422_2400为空，已被删除.
# P2722_1422_2999为空，已被删除.
# P2722_1422_800为空，已被删除.
# P2722_800_0为空，已被删除.
# P2722_800_1600为空，已被删除.
# P2722_800_2400为空，已被删除.
# P2722_800_2999为空，已被删除.
# P2722_800_800为空，已被删除.
# P2724_0_0为空，已被删除.
# P2724_0_3517为空，已被删除.
# P2724_0_800为空，已被删除.
# P2724_1432_0为空，已被删除.
# P2724_1432_1600为空，已被删除.
# P2724_1432_2400为空，已被删除.
# P2724_1432_3517为空，已被删除.
# P2724_1432_800为空，已被删除.
# P2724_800_800为空，已被删除.
# P2745_0_1600为空，已被删除.
# P2745_1475_0为空，已被删除.
# P2745_1475_1600为空，已被删除.
# P2745_1475_2400为空，已被删除.
# P2745_1475_2740为空，已被删除.
# P2745_1475_800为空，已被删除.
# P2745_800_0为空，已被删除.
# P2745_800_1600为空，已被删除.
# P2745_800_2400为空，已被删除.
# P2745_800_2740为空，已被删除.
# P2745_800_800为空，已被删除.
# P2766_0_1600为空，已被删除.
# P2766_0_3200为空，已被删除.
# P2766_0_4000为空，已被删除.
# P2766_0_4421为空，已被删除.
# P2766_1600_0为空，已被删除.
# P2766_1600_2400为空，已被删除.
# P2766_1600_4000为空，已被删除.
# P2766_1600_4421为空，已被删除.
# P2766_1600_800为空，已被删除.
# P2766_2400_1600为空，已被删除.
# P2766_2400_2400为空，已被删除.
# P2766_2400_4000为空，已被删除.
# P2766_2400_4421为空，已被删除.
# P2766_3200_2400为空，已被删除.
# P2766_4000_2400为空，已被删除.
# P2766_4000_800为空，已被删除.
# P2766_4572_0为空，已被删除.
# P2766_4572_1600为空，已被删除.
# P2766_4572_800为空，已被删除.
# P2766_800_1600为空，已被删除.
# P2781_0_2400为空，已被删除.
# P2781_0_2531为空，已被删除.
# P2781_1187_2400为空，已被删除.
# P2781_1187_2531为空，已被删除.
# P2781_800_2531为空，已被删除.
# P2794_0_3200为空，已被删除.
# P2794_0_3368为空，已被删除.
# P2794_1600_0为空，已被删除.
# P2794_1600_800为空，已被删除.
# P2794_2400_1600为空，已被删除.
# P2794_2400_800为空，已被删除.
# P2794_3200_800为空，已被删除.
# P2794_800_0为空，已被删除.
# P2794_800_3200为空，已被删除.
# P2794_800_3368为空，已被删除.
# P2794_800_800为空，已被删除.
# P2802_0_1600为空，已被删除.
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11184\4218758408.py in <module>
#      25 out_img_floder = r'G:\DOTA\train\11\val\images'
#      26
# ---> 27 delete_empty_txt(out_txt_floder, out_img_floder)
#
# ~\AppData\Local\Temp\ipykernel_11184\4218758408.py in delete_empty_txt(out_txt_floder, out_img_floder)
#      16             #  若该txt为空,删除txt及其对应图像
#      17             if(data == ""):
# ---> 18                 os.remove(txt_path)
#      19                 os.remove(img_path)
#      20                 print('{}为空，已被删除.'.format(name))
#
# PermissionError: [WinError 32] 另一个程序正在使用此文件，进程无法访问。: 'G:\\DOTA\\train\\11\\val\\new_lables\\P2802_4225_800.txt'

# %% [markdown]
# # 实现从png到jpg

# %%
# 实现从png到jpg

import dota_utils as util
import cv2
import os

# this code is used to convert image formats
# from PNG to JPG
def imageformatTrans(srcpath, dstpath, format):
    filelist = util.GetFileFromThisRootDir(srcpath)
    for fullname in filelist:
        img = cv2.imread(fullname)
        basename = util.custombasename(fullname)
        dstname = os.path.join(dstpath, basename + format)
        cv2.imwrite(dstname, img)

if __name__ == '__main__':
    # an example

    imageformatTrans(r'D:\DOTA\baseball_diamond\aug_images', r'G:\DOTA\baseball_diamond\images',
                     '.jpg')

# %% [markdown]
# # 数据增强

# %%
import time
import random
import cv2 as cv
import os
import math
import numpy as np
from skimage import exposure
import shutil


# 调整亮度
def changeLight(img, inputtxt, outputiamge, outputtxt):
    # random.seed(int(time.time()))
    flag = random.uniform(0.5, 1.5)  # flag>1为调暗,小于1为调亮
    #label = round(flag, 2)
    label = int(flag)
    (filepath, tempfilename) = os.path.split(inputtxt)
    (filename, extension) = os.path.splitext(tempfilename)
    outputiamge = os.path.join(outputiamge + "/" + filename + "_" + str(label) + ".png")
    outputtxt = os.path.join(outputtxt + "/" + filename + "_" + str(label) + extension)

    ima_gamma = exposure.adjust_gamma(img, 0.5)

    shutil.copyfile(inputtxt, outputtxt)
    cv.imwrite(outputiamge, ima_gamma)


# 添加高斯噪声
def gasuss_noise(image, inputtxt, outputiamge, outputtxt, mean=0, var=0.01):
    '''
    mean : 均值
    var : 方差
    '''
    image = np.array(image / 255, dtype=float)
    noise = np.random.normal(mean, var ** 0.5, image.shape)
    out = image + noise

    if out.min() < 0:
        low_clip = -1.
    else:
        low_clip = 0.
    out = np.clip(out, low_clip, 1.0)
    out = np.uint8(out * 255)

    (filepath, tempfilename) = os.path.split(inputtxt)
    (filename, extension) = os.path.splitext(tempfilename)
    outputiamge = os.path.join(outputiamge + "/" + filename + "_gasunoise_" + str(int(mean)) + "_" + str(int(var)) + ".png")
    outputtxt = os.path.join(outputtxt + "/" + filename + "_gasunoise_" + str(int(mean)) + "_" + str(int(var)) + extension)

    shutil.copyfile(inputtxt, outputtxt)
    cv.imwrite(outputiamge, out)


# 调整对比度
def ContrastAlgorithm(rgb_img, inputtxt, outputiamge, outputtxt):
    img_shape = rgb_img.shape
    temp_imag = np.zeros(img_shape, dtype=float)
    for num in range(0, 3):
        # 通过直方图正规化增强对比度
        in_image = rgb_img[:, :, num]
        # 求输入图片像素最大值和最小值
        Imax = np.max(in_image)
        Imin = np.min(in_image)
        # 要输出的最小灰度级和最大灰度级
        Omin, Omax = 0, 255
        # 计算a 和 b的值
        a = float(Omax - Omin) / (Imax - Imin)
        b = Omin - a * Imin
        # 矩阵的线性变化
        out_image = a * in_image + b
        # 数据类型的转化
        out_image = out_image.astype(np.uint8)
        temp_imag[:, :, num] = out_image
    (filepath, tempfilename) = os.path.split(inputtxt)
    (filename, extension) = os.path.splitext(tempfilename)
    outputiamge = os.path.join(outputiamge + "/" + filename + "_contrastAlgorithm" + ".png")
    outputtxt = os.path.join(outputtxt + "/" + filename + "_contrastAlgorithm" + extension)
    shutil.copyfile(inputtxt, outputtxt)
    cv.imwrite(outputiamge, temp_imag)


# 旋转
def rotate_img_bbox(img, inputtxt, temp_outputiamge, temp_outputtxt, angle, scale=1):
    nAgree = angle
    size = img.shape
    w = size[1]
    h = size[0]
    for numAngle in range(0, len(nAgree)):
        dRot = nAgree[numAngle] * np.pi / 180
        dSinRot = math.sin(dRot)
        dCosRot = math.cos(dRot)

        nw = (abs(np.sin(dRot) * h) + abs(np.cos(dRot) * w)) * scale
        nh = (abs(np.cos(dRot) * h) + abs(np.sin(dRot) * w)) * scale

        (filepath, tempfilename) = os.path.split(inputtxt)
        (filename, extension) = os.path.splitext(tempfilename)
        outputiamge = os.path.join(temp_outputiamge + "/" + filename + "_rotate_" + str(nAgree[numAngle]) + ".png")
        outputtxt = os.path.join(temp_outputtxt + "/" + filename + "_rotate_" + str(nAgree[numAngle]) + extension)

        rot_mat = cv.getRotationMatrix2D((nw * 0.5, nh * 0.5), nAgree[numAngle], scale)
        rot_move = np.dot(rot_mat, np.array([(nw - w) * 0.5, (nh - h) * 0.5, 0]))
        rot_mat[0, 2] += rot_move[0]
        rot_mat[1, 2] += rot_move[1]
        # 仿射变换
        rotat_img = cv.warpAffine(img, rot_mat, (int(math.ceil(nw)), int(math.ceil(nh))), flags=cv.INTER_LANCZOS4)
        cv.imwrite(outputiamge, rotat_img)

        save_txt = open(outputtxt, 'w')
        f = open(inputtxt)
        for line in f.readlines():
            line = line.split(" ")
            x1 = float(line[0])
            y1 = float(line[1])
            x2 = float(line[2])
            y2 = float(line[3])
            x3 = float(line[4])
            y3 = float(line[5])
            x4 = float(line[6])
            y4 = float(line[7])
            category = str(line[8])
            dif = str(line[9])

            point1 = np.dot(rot_mat, np.array([x1, y1, 1]))
            point2 = np.dot(rot_mat, np.array([x2, y2, 1]))
            point3 = np.dot(rot_mat, np.array([x3, y3, 1]))
            point4 = np.dot(rot_mat, np.array([x4, y4, 1]))
            x1 = round(point1[0], 3)
            y1 = round(point1[1], 3)
            x2 = round(point2[0], 3)
            y2 = round(point2[1], 3)
            x3 = round(point3[0], 3)
            y3 = round(point3[1], 3)
            x4 = round(point4[0], 3)
            y4 = round(point4[1], 3)
            # string = str(x1) + " " + str(y1) + " " + str(x2) + " " + str(y2) + " " + str(x3) + " " + str(y3) + " " + str(x4) + " " + str(y4) + " " + category + " " + dif
            string = str(int(x1)) + " " + str(int(y1)) + " " + str(int(x2)) + " " + str(int(y2)) + " " + str(
                int(x3)) + " " + str(int(y3)) + " " + str(int(x4)) + " " + str(int(y4)) + " " + category + " " + dif
            save_txt.write(string)

# 翻转图像
def filp_pic_bboxes(img, inputtxt, outputiamge, outputtxt):
    (filepath, tempfilename) = os.path.split(inputtxt)
    (filename, extension) = os.path.splitext(tempfilename)
    output_vert_flip_img = os.path.join(outputiamge + "/" + filename + "_vert_flip" + ".png")
    output_vert_flip_txt = os.path.join(outputtxt + "/" + filename + "_vert_flip" + extension)
    output_horiz_flip_img = os.path.join(outputiamge + "/" + filename + "_horiz_flip" + ".png")
    output_horiz_flip_txt = os.path.join(outputtxt + "/" + filename + "_horiz_flip" + extension)

    h, w, _ = img.shape
    # 垂直翻转
    vert_flip_img = cv.flip(img, 1)
    cv.imwrite(output_vert_flip_img, vert_flip_img)
    # 水平翻转
    horiz_flip_img = cv.flip(img, 0)
    cv.imwrite(output_horiz_flip_img, horiz_flip_img)
    # ---------------------- 调整boundingbox ----------------------
    save_vert_txt = open(output_vert_flip_txt, 'w')
    save_horiz_txt = open(output_horiz_flip_txt, 'w')
    f = open(inputtxt)
    for line in f.readlines():
        line = line.split(" ")
        x1 = float(line[0])
        y1 = float(line[1])
        x2 = float(line[2])
        y2 = float(line[3])
        x3 = float(line[4])
        y3 = float(line[5])
        x4 = float(line[6])
        y4 = float(line[7])
        category = str(line[8])
        dif = str(line[9])

        vert_string = str(int(round(w - x1, 3))) + " " + str(int(y1)) + " " + str(int(round(w - x2, 3))) + " " + str(
            int(y2)) + " " + str(int(round(w - x3, 3))) + " " + str(int(y3)) + " " + str(
            int(round(w - x4, 3))) + " " + str(int(y4)) + " " + category + " " + dif
        horiz_string = str(int(x1)) + " " + str(int(round(h - y1, 3))) + " " + str(int(x2)) + " " + str(
            int(round(h - y2, 3))) + " " + str(int(x3)) + " " + str(int(round(h - y3, 3))) + " " + str(
            int(x4)) + " " + str(int(round(h - y4, 3))) + " " + category + " " + dif

        save_horiz_txt.write(horiz_string)
        save_vert_txt.write(vert_string)


# 平移图像
def shift_pic_bboxes(img, inputtxt, outputiamge, outputtxt):
    w = img.shape[1]
    h = img.shape[0]
    x_min = w  # 裁剪后的包含所有目标框的最小的框
    x_max = 0
    y_min = h
    y_max = 0
    f = open(inputtxt)
    for line in f.readlines():
        line = line.split(" ")
        x1 = float(line[0])
        y1 = float(line[1])
        x2 = float(line[2])
        y2 = float(line[3])
        x3 = float(line[4])
        y3 = float(line[5])
        x4 = float(line[6])
        y4 = float(line[7])
        category = str(line[8])
        dif = str(line[9])

        x_min = min(x_min, x1, x2, x3, x4)
        y_min = min(y_min, y1, y2, y3, y4)
        x_max = max(x_max, x1, x2, x3, x4)
        y_max = max(y_max, y1, y2, y3, y4)

    d_to_left = x_min  # 包含所有目标框的最大左移动距离
    d_to_right = w - x_max  # 包含所有目标框的最大右移动距离
    d_to_top = y_min  # 包含所有目标框的最大上移动距离
    d_to_bottom = h - y_max  # 包含所有目标框的最大下移动距离

    x = random.uniform(-(d_to_left - 1) / 3, (d_to_right - 1) / 3)
    y = random.uniform(-(d_to_top - 1) / 3, (d_to_bottom - 1) / 3)

    (filepath, tempfilename) = os.path.split(inputtxt)
    (filename, extension) = os.path.splitext(tempfilename)
    if x >= 0 and y >= 0:
        outputiamge = os.path.join(
            outputiamge + "/" + filename + "_shift_" + str(int(round(x, 3))) + "_" + str(int(round(y, 3))) + ".png")
        outputtxt = os.path.join(
            outputtxt + "/" + filename + "_shift_" + str(int(round(x, 3))) + "_" + str(int(round(y, 3))) + extension)
    elif x >= 0 and y < 0:
        outputiamge = os.path.join(
            outputiamge + "/" + filename + "_shift_" + str(int(round(x, 3))) + "__" + str(int(round(abs(y), 3))) + ".png")
        outputtxt = os.path.join(
            outputtxt + "/" + filename + "_shift_" + str(int(round(x, 3))) + "__" + str(int(round(abs(y), 3))) + extension)
    elif x < 0 and y >= 0:
        outputiamge = os.path.join(
            outputiamge + "/" + filename + "_shift__" + str(int(round(abs(x), 3))) + "_" + str(int(round(y, 3))) + ".png")
        outputtxt = os.path.join(
            outputtxt + "/" + filename + "_shift__" + str(int(round(abs(x), 3))) + "_" + str(int(round(y, 3))) + extension)
    elif x < 0 and y < 0:
        outputiamge = os.path.join(
            outputiamge + "/" + filename + "_shift__" + str(int(round(abs(x), 3))) + "__" + str(int(round(abs(y), 3))) + ".png")
        outputtxt = os.path.join(
            outputtxt + "/" + filename + "_shift__" + str(int(round(abs(x), 3))) + "__" + str(int(round(abs(y), 3))) + extension)

    M = np.float32([[1, 0, x], [0, 1, y]])  # x为向左或右移动的像素值,正为向右负为向左; y为向上或者向下移动的像素值,正为向下负为向上
    shift_img = cv.warpAffine(img, M, (img.shape[1], img.shape[0]))
    cv.imwrite(outputiamge, shift_img)
    # ---------------------- 平移boundingbox ----------------------
    save_txt = open(outputtxt, "w")
    f = open(inputtxt)
    for line in f.readlines():
        line = line.split(" ")
        x1 = float(line[0])
        y1 = float(line[1])
        x2 = float(line[2])
        y2 = float(line[3])
        x3 = float(line[4])
        y3 = float(line[5])
        x4 = float(line[6])
        y4 = float(line[7])
        category = str(line[8])
        dif = str(line[9])
        shift_str = str(int(round(x1 + x, 3))) + " " + str(int(round(y1 + y, 3))) + " " + str(int(round(x2 + x, 3))) + " " + str(int(round(y2 + y, 3))) + " " + str(int(round(x3 + x, 3))) + " " + str(int(round(y3 + y, 3))) + " " + str(int(round(x4 + x, 3))) + " " + str(int(round(y4 + y, 3))) + " " + category + " " + dif
        save_txt.write(shift_str)


# 裁剪图像
def crop_img_bboxes(img, inputtxt, outputiamge, outputtxt):
    # ---------------------- 裁剪图像 ----------------------
    w = img.shape[1]
    h = img.shape[0]
    x_min = 0  # 裁剪后的包含所有目标框的最小的框
    x_max = w
    y_min = 0
    y_max = h
    f = open(inputtxt)
    for line in f.readlines():
        line = line.split(" ")
        x1 = float(line[0])
        y1 = float(line[1])
        x2 = float(line[2])
        y2 = float(line[3])
        x3 = float(line[4])
        y3 = float(line[5])
        x4 = float(line[6])
        y4 = float(line[7])
        category = str(line[8])
        dif = str(line[9])

        x_min = min(x_min, x1, x2, x3, x4)
        y_min = min(y_min, y1, y2, y3, y4)
        x_max = max(x_max, x1, x2, x3, x4)
        y_max = max(y_max, y1, y2, y3, y4)

    d_to_left = x_min  # 包含所有目标框的最小框到左边的距离
    d_to_right = w - x_max  # 包含所有目标框的最小框到右边的距离
    d_to_top = y_min  # 包含所有目标框的最小框到顶端的距离
    d_to_bottom = h - y_max  # 包含所有目标框的最小框到底部的距离
    # 随机扩展这个最小框
    crop_x_min = int(x_min - random.uniform(0, d_to_left))
    crop_y_min = int(y_min - random.uniform(0, d_to_top))
    crop_x_max = int(x_max + random.uniform(0, d_to_right))
    crop_y_max = int(y_max + random.uniform(0, d_to_bottom))
    # 随机扩展这个最小框 , 防止别裁的太小
    # crop_x_min = int(x_min - random.uniform(d_to_left//2, d_to_left))
    # crop_y_min = int(y_min - random.uniform(d_to_top//2, d_to_top))
    # crop_x_max = int(x_max + random.uniform(d_to_right//2, d_to_right))
    # crop_y_max = int(y_max + random.uniform(d_to_bottom//2, d_to_bottom))
    # 确保不要越界
    crop_x_min = max(0, crop_x_min)
    crop_y_min = max(0, crop_y_min)
    crop_x_max = min(w, crop_x_max)
    crop_y_max = min(h, crop_y_max)
    crop_img = img[crop_y_min:crop_y_max, crop_x_min:crop_x_max]

    (filepath, tempfilename) = os.path.split(inputtxt)
    (filename, extension) = os.path.splitext(tempfilename)
    outputiamge = os.path.join(outputiamge + "/" + filename + "_crop_" + str(crop_x_min) + "_" +
                               str(crop_y_min) + "_" + str(crop_x_max) + "_" +
                               str(crop_y_max) + ".png")
    outputtxt = os.path.join(outputtxt + "/" + filename + "_crop_" + str(crop_x_min) + "_" +
                             str(crop_y_min) + "_" + str(crop_x_max) + "_" +
                             str(crop_y_max) + extension)
    cv.imwrite(outputiamge, crop_img)
    # ---------------------- 裁剪boundingbox ----------------------
    # 裁剪后的boundingbox坐标计算
    save_txt = open(outputtxt, "w")
    f = open(inputtxt)
    for line in f.readlines():
        line = line.split(" ")
        x1 = float(line[0])
        y1 = float(line[1])
        x2 = float(line[2])
        y2 = float(line[3])
        x3 = float(line[4])
        y3 = float(line[5])
        x4 = float(line[6])
        y4 = float(line[7])
        category = str(line[8])
        dif = str(line[9])
        crop_str = str(int(round(x1 - crop_x_min, 3))) + " " + str(int(round(y1 - crop_y_min, 3))) + " " + str(int(round(x2 - crop_x_min, 3))) + " " + str(int(round(y2 - crop_y_min, 3))) + " " + str(int(round(x3 - crop_x_min, 3))) + " " + str(int(round(y3 - crop_y_min, 3))) + " " + str(int(round(x4 - crop_x_min, 3))) + " " + str(int(round(y4 - crop_y_min, 3))) + " " + category + " " + dif
        save_txt.write(crop_str)

if __name__ == '__main__':
    inputiamge = "G://DOTA//train//object//soccer-ball-field//images"
    inputtxt = "G://DOTA//train//object//soccer-ball-field//labels"
    outputiamge = "G://DOTA//train//all_total//soccer-ball-field//images"
    outputtxt = "G://DOTA//train//all_total//soccer-ball-field//labels"
    angle = [30, 60, 90, 120, 150, 180]
    #angle = [90]
    tempfilename = os.listdir(inputiamge)
    for file in tempfilename:
        (filename, extension) = os.path.splitext(file)
        input_image = os.path.join(inputiamge + "//" + file)
        input_txt = os.path.join(inputtxt + "//" + filename + ".txt")

        img = cv.imread(input_image)
        # 图像亮度变化
        changeLight(img,input_txt,outputiamge,outputtxt)
        # 加高斯噪声
        gasuss_noise(img, input_txt, outputiamge, outputtxt, mean=0, var=0.001)
        # 改变图像对比度
        ContrastAlgorithm(img, input_txt, outputiamge, outputtxt)
        # 图像旋转
        rotate_img_bbox(img, input_txt, outputiamge, outputtxt, angle)
        # 图像镜像
        filp_pic_bboxes(img, input_txt, outputiamge, outputtxt)
        # 平移
        shift_pic_bboxes(img, input_txt, outputiamge, outputtxt)
        # 剪切
        crop_img_bboxes(img, input_txt, outputiamge, outputtxt)
    print("finished!")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10872\2028783120.py in <module>
#     353         input_txt = os.path.join(inputtxt + "//" + filename + ".txt")
#     354
# --> 355         img = cv.imread(input_image)
#     356         # 图像亮度变化
#     357         changeLight(img,input_txt,outputiamge,outputtxt)
#
# KeyboardInterrupt:

# %% [markdown]
# # txt2csv

# %%
### txt转csv文件
import numpy as np
import os
from PIL import Image
import pandas as pd
#from torch import float, int
file_name_path=r"G:\DOTA\train\new_data\train\\"
images_path=file_name_path+"images\\"
labelS_path=file_name_path+"labels\\"
file_name=os.listdir(labelS_path)
#dic_name={0: 'small-vehicle',1: 'large-vehicle',2: 'plane',3: 'storage-tank',4: 'ship',5: 'harbor',6: 'ground-track-field',7: 'soccer-ball-field',8: 'tennis-court',9: 'swimming-pool',
#10: 'baseball-diamond',11: 'roundabout',12: 'basketball-court',13: 'bridge',14: 'helicopter'}
dic_name={0: 'large-vehicle',1: 'plane',2: 'ship',3: 'harbor',4: 'tennis-court',5: 'baseball-diamond',6: 'basketball-court',7: 'helicopter'}
# file=open(r"F:\taididata\lastdata\lastdata\manual_label_images\labels\00029.txt","r",encoding='UTF-8')
# file.read()
data=[]
for i in file_name:
    ii=i.split(".")
    # print(i,i[0:6]) 
    cv=Image.open(images_path+ii[0]+".png")
    file=open(labelS_path+i,"r",)
    categroy_list=file.read().splitlines(True)
    # print(categroy_list)
    for _ in categroy_list:
        csv_=[]
        list_=[float(i) for i in _.strip().split(" ")]
        # print(list_)
        csv_.append(ii[0]+".png")
        csv_.append(int(list_[0]))
        csv_.append(dic_name[int(list_[0])])
        #csv_.append(int(list_[1]*cv.width))
        #csv_.append(int(list_[2]*cv.height))
        csv_.append(int((list_[1]*cv.width)-(list_[3]*cv.width/2)))
        csv_.append(int((list_[2]*cv.height)-(list_[4]*cv.height/2)))
        csv_.append(int((list_[1]*cv.width)+(list_[3]*cv.width/2)))
        csv_.append(int((list_[2]*cv.height)+(list_[4]*cv.height/2)))
        
        # csv_
        data.append(csv_)
data_csv=pd.DataFrame(data,columns=['文件名','分类号','类型','左上角x坐标','左上角y坐标','右下角x坐标','右下角y坐标'])
data_csv.head(3)
data_csv.to_csv("G://DOTA//new_aug.csv",encoding='utf-8')

# %%
##制作label list
import os
 
def listdir(path, list_name):  # 传入存储的list
    for file in os.listdir(path):
        file_path = os.path.join(path, file)
        if os.path.isdir(file_path):
            listdir(file_path, list_name)
        else:
            list_name.append(file_path)
 
 
list_name = []
path = 'G://DOTA//11//images11'  # 文件夹路径
listdir(path, list_name)
print(list_name)
 
with open('./list.txt', 'w') as f:  # 要存入的txt
    write = ''
    for i in list_name:
        write = write + str(i) + '\n'
    f.write(write)
# Out:
# ['G://DOTA//11//images11\\P0000_0_0_0.58.png', 'G://DOTA//11//images11\\P0000_0_0_0.89.png', 'G://DOTA//11//images11\\P0000_0_0_1.44.jpg', 'G://DOTA//11//images11\\P0000_0_0_contrastAlgorithm.jpg', 'G://DOTA//11//images11\\P0000_0_0_contrastAlgorithm.png', 'G://DOTA//11//images11\\P0000_0_0_crop_0_0_1000_1000.png', 'G://DOTA//11//images11\\P0000_0_0_gasunoise_0_0.001.jpg', 'G://DOTA//11//images11\\P0000_0_0_gasunoise_0_0.001.png', 'G://DOTA//11//images11\\P0000_0_0_horiz_flip.png', 'G://DOTA//11//images11\\P0000_0_0_rotate_120.png', 'G://DOTA//11//images11\\P0000_0_0_rotate_150.png', 'G://DOTA//11//images11\\P0000_0_0_rotate_180.png', 'G://DOTA//11//images11\\P0000_0_0_rotate_30.jpg', 'G://DOTA//11//images11\\P0000_0_0_rotate_30.png', 'G://DOTA//11//images11\\P0000_0_0_rotate_60.png', 'G://DOTA//11//images11\\P0000_0_0_rotate_90.png', 'G://DOTA//11//images11\\P0000_0_0_shift__38.256_78.732.png', 'G://DOTA//11//images11\\P0000_0_0_vert_flip.png', 'G://DOTA//11//images11\\P0000_0_800_0.62.png', 'G://DOTA//11//images11\\P0000_0_800_contrastAlgorithm.png', 'G://DOTA//11//images11\\P0000_0_800_crop_0_0_1000_1000.png', 'G://DOTA//11//images11\\P0000_0_800_gasunoise_0_0.001.png', 'G://DOTA//11//images11\\P0000_0_800_horiz_flip.png', 'G://DOTA//11//images11\\P0000_0_800_rotate_120.png', 'G://DOTA//11//images11\\P0000_0_800_rotate_150.png', 'G://DOTA//11//images11\\P0000_0_800_rotate_180.png', 'G://DOTA//11//images11\\P0000_0_800_rotate_30.png', 'G://DOTA//11//images11\\P0000_0_800_rotate_60.png', 'G://DOTA//11//images11\\P0000_0_800_rotate_90.png', 'G://DOTA//11//images11\\P0000_0_800_shift_176.918__21.716.png', 'G://DOTA//11//images11\\P0000_0_800_vert_flip.png']

# %%
#注意 cv2.CV_IMWRITE_JPEG_QUALITY  设置图片格式为.jpeg或者.jpg的图片质量，其值为0---100（数值越大质量越高），默认95

import time
import random
import cv2 as cv
import os
import math
import numpy as np
from skimage import exposure
import shutil


# 调整亮度
def changeLight(img, inputtxt, outputiamge, outputtxt):
    # random.seed(int(time.time()))
    flag = random.uniform(0.5, 1.5)  # flag>1为调暗,小于1为调亮
    #label = round(flag, 2)
    label = int(flag)
    (filepath, tempfilename) = os.path.split(inputtxt)
    (filename, extension) = os.path.splitext(tempfilename)
    outputiamge = os.path.join(outputiamge + "/" + filename + "_" + str(label) + ".jpg")
    outputtxt = os.path.join(outputtxt + "/" + filename + "_" + str(label) + extension)

    ima_gamma = exposure.adjust_gamma(img, 0.5)

    shutil.copyfile(inputtxt, outputtxt)
    cv.imwrite(outputiamge, ima_gamma,[int(cv.IMWRITE_JPEG_QUALITY), 50])


# 添加高斯噪声
def gasuss_noise(image, inputtxt, outputiamge, outputtxt, mean=0, var=0.01):
    '''
    mean : 均值
    var : 方差
    '''
    image = np.array(image / 255, dtype=float)
    noise = np.random.normal(mean, var ** 0.5, image.shape)
    out = image + noise

    if out.min() < 0:
        low_clip = -1.
    else:
        low_clip = 0.
    out = np.clip(out, low_clip, 1.0)
    out = np.uint8(out * 255)

    (filepath, tempfilename) = os.path.split(inputtxt)
    (filename, extension) = os.path.splitext(tempfilename)
    outputiamge = os.path.join(outputiamge + "/" + filename + "_gasunoise_" + str(int(mean)) + "_" + str(int(var)) + ".jpg")
    outputtxt = os.path.join(outputtxt + "/" + filename + "_gasunoise_" + str(int(mean)) + "_" + str(int(var)) + extension)

    shutil.copyfile(inputtxt, outputtxt)
    cv.imwrite(outputiamge, out,[int(cv.IMWRITE_JPEG_QUALITY), 50])


# 调整对比度
def ContrastAlgorithm(rgb_img, inputtxt, outputiamge, outputtxt):
    img_shape = rgb_img.shape
    temp_imag = np.zeros(img_shape, dtype=float)
    for num in range(0, 3):
        # 通过直方图正规化增强对比度
        in_image = rgb_img[:, :, num]
        # 求输入图片像素最大值和最小值
        Imax = np.max(in_image)
        Imin = np.min(in_image)
        # 要输出的最小灰度级和最大灰度级
        Omin, Omax = 0, 255
        # 计算a 和 b的值
        a = float(Omax - Omin) / (Imax - Imin)
        b = Omin - a * Imin
        # 矩阵的线性变化
        out_image = a * in_image + b
        # 数据类型的转化
        out_image = out_image.astype(np.uint8)
        temp_imag[:, :, num] = out_image
    (filepath, tempfilename) = os.path.split(inputtxt)
    (filename, extension) = os.path.splitext(tempfilename)
    outputiamge = os.path.join(outputiamge + "/" + filename + "_contrastAlgorithm" + ".jpg")
    outputtxt = os.path.join(outputtxt + "/" + filename + "_contrastAlgorithm" + extension)
    shutil.copyfile(inputtxt, outputtxt)
    cv.imwrite(outputiamge, temp_imag,[int(cv.IMWRITE_JPEG_QUALITY), 50])


# 旋转
def rotate_img_bbox(img, inputtxt, temp_outputiamge, temp_outputtxt, angle, scale=1):
    nAgree = angle
    size = img.shape
    w = size[1]
    h = size[0]
    for numAngle in range(0, len(nAgree)):
        dRot = nAgree[numAngle] * np.pi / 180
        dSinRot = math.sin(dRot)
        dCosRot = math.cos(dRot)

        nw = (abs(np.sin(dRot) * h) + abs(np.cos(dRot) * w)) * scale
        nh = (abs(np.cos(dRot) * h) + abs(np.sin(dRot) * w)) * scale

        (filepath, tempfilename) = os.path.split(inputtxt)
        (filename, extension) = os.path.splitext(tempfilename)
        outputiamge = os.path.join(temp_outputiamge + "/" + filename + "_rotate_" + str(nAgree[numAngle]) + ".jpg")
        outputtxt = os.path.join(temp_outputtxt + "/" + filename + "_rotate_" + str(nAgree[numAngle]) + extension)

        rot_mat = cv.getRotationMatrix2D((nw * 0.5, nh * 0.5), nAgree[numAngle], scale)
        rot_move = np.dot(rot_mat, np.array([(nw - w) * 0.5, (nh - h) * 0.5, 0]))
        rot_mat[0, 2] += rot_move[0]
        rot_mat[1, 2] += rot_move[1]
        # 仿射变换
        rotat_img = cv.warpAffine(img, rot_mat, (int(math.ceil(nw)), int(math.ceil(nh))), flags=cv.INTER_LANCZOS4)
        cv.imwrite(outputiamge, rotat_img,[int(cv.IMWRITE_JPEG_QUALITY), 50])

        save_txt = open(outputtxt, 'w')
        f = open(inputtxt)
        for line in f.readlines():
            line = line.split(" ")
            x1 = float(line[0])
            y1 = float(line[1])
            x2 = float(line[2])
            y2 = float(line[3])
            x3 = float(line[4])
            y3 = float(line[5])
            x4 = float(line[6])
            y4 = float(line[7])
            category = str(line[8])
            dif = str(line[9])

            point1 = np.dot(rot_mat, np.array([x1, y1, 1]))
            point2 = np.dot(rot_mat, np.array([x2, y2, 1]))
            point3 = np.dot(rot_mat, np.array([x3, y3, 1]))
            point4 = np.dot(rot_mat, np.array([x4, y4, 1]))
            x1 = round(point1[0], 3)
            y1 = round(point1[1], 3)
            x2 = round(point2[0], 3)
            y2 = round(point2[1], 3)
            x3 = round(point3[0], 3)
            y3 = round(point3[1], 3)
            x4 = round(point4[0], 3)
            y4 = round(point4[1], 3)
            # string = str(x1) + " " + str(y1) + " " + str(x2) + " " + str(y2) + " " + str(x3) + " " + str(y3) + " " + str(x4) + " " + str(y4) + " " + category + " " + dif
            string = str(int(x1)) + " " + str(int(y1)) + " " + str(int(x2)) + " " + str(int(y2)) + " " + str(
                int(x3)) + " " + str(int(y3)) + " " + str(int(x4)) + " " + str(int(y4)) + " " + category + " " + dif
            save_txt.write(string)

# 翻转图像
def filp_pic_bboxes(img, inputtxt, outputiamge, outputtxt):
    (filepath, tempfilename) = os.path.split(inputtxt)
    (filename, extension) = os.path.splitext(tempfilename)
    output_vert_flip_img = os.path.join(outputiamge + "/" + filename + "_vert_flip" + ".jpg")
    output_vert_flip_txt = os.path.join(outputtxt + "/" + filename + "_vert_flip" + extension)
    output_horiz_flip_img = os.path.join(outputiamge + "/" + filename + "_horiz_flip" + ".jpg")
    output_horiz_flip_txt = os.path.join(outputtxt + "/" + filename + "_horiz_flip" + extension)

    h, w, _ = img.shape
    # 垂直翻转
    vert_flip_img = cv.flip(img, 1)
    cv.imwrite(output_vert_flip_img, vert_flip_img,[int(cv.IMWRITE_JPEG_QUALITY), 50])
    # 水平翻转
    horiz_flip_img = cv.flip(img, 0)
    cv.imwrite(output_horiz_flip_img, horiz_flip_img,[int(cv.IMWRITE_JPEG_QUALITY), 50])
    # ---------------------- 调整boundingbox ----------------------
    save_vert_txt = open(output_vert_flip_txt, 'w')
    save_horiz_txt = open(output_horiz_flip_txt, 'w')
    f = open(inputtxt)
    for line in f.readlines():
        line = line.split(" ")
        x1 = float(line[0])
        y1 = float(line[1])
        x2 = float(line[2])
        y2 = float(line[3])
        x3 = float(line[4])
        y3 = float(line[5])
        x4 = float(line[6])
        y4 = float(line[7])
        category = str(line[8])
        dif = str(line[9])

        vert_string = str(int(round(w - x1, 3))) + " " + str(int(y1)) + " " + str(int(round(w - x2, 3))) + " " + str(
            int(y2)) + " " + str(int(round(w - x3, 3))) + " " + str(int(y3)) + " " + str(
            int(round(w - x4, 3))) + " " + str(int(y4)) + " " + category + " " + dif
        horiz_string = str(int(x1)) + " " + str(int(round(h - y1, 3))) + " " + str(int(x2)) + " " + str(
            int(round(h - y2, 3))) + " " + str(int(x3)) + " " + str(int(round(h - y3, 3))) + " " + str(
            int(x4)) + " " + str(int(round(h - y4, 3))) + " " + category + " " + dif

        save_horiz_txt.write(horiz_string)
        save_vert_txt.write(vert_string)


# 平移图像
def shift_pic_bboxes(img, inputtxt, outputiamge, outputtxt):
    w = img.shape[1]
    h = img.shape[0]
    x_min = w  # 裁剪后的包含所有目标框的最小的框
    x_max = 0
    y_min = h
    y_max = 0
    f = open(inputtxt)
    for line in f.readlines():
        line = line.split(" ")
        x1 = float(line[0])
        y1 = float(line[1])
        x2 = float(line[2])
        y2 = float(line[3])
        x3 = float(line[4])
        y3 = float(line[5])
        x4 = float(line[6])
        y4 = float(line[7])
        category = str(line[8])
        dif = str(line[9])

        x_min = min(x_min, x1, x2, x3, x4)
        y_min = min(y_min, y1, y2, y3, y4)
        x_max = max(x_max, x1, x2, x3, x4)
        y_max = max(y_max, y1, y2, y3, y4)

    d_to_left = x_min  # 包含所有目标框的最大左移动距离
    d_to_right = w - x_max  # 包含所有目标框的最大右移动距离
    d_to_top = y_min  # 包含所有目标框的最大上移动距离
    d_to_bottom = h - y_max  # 包含所有目标框的最大下移动距离

    x = random.uniform(-(d_to_left - 1) / 3, (d_to_right - 1) / 3)
    y = random.uniform(-(d_to_top - 1) / 3, (d_to_bottom - 1) / 3)

    (filepath, tempfilename) = os.path.split(inputtxt)
    (filename, extension) = os.path.splitext(tempfilename)
    if x >= 0 and y >= 0:
        outputiamge = os.path.join(
            outputiamge + "/" + filename + "_shift_" + str(int(round(x, 3))) + "_" + str(int(round(y, 3))) + ".jpg")
        outputtxt = os.path.join(
            outputtxt + "/" + filename + "_shift_" + str(int(round(x, 3))) + "_" + str(int(round(y, 3))) + extension)
    elif x >= 0 and y < 0:
        outputiamge = os.path.join(
            outputiamge + "/" + filename + "_shift_" + str(int(round(x, 3))) + "__" + str(int(round(abs(y), 3))) + ".jpg")
        outputtxt = os.path.join(
            outputtxt + "/" + filename + "_shift_" + str(int(round(x, 3))) + "__" + str(int(round(abs(y), 3))) + extension)
    elif x < 0 and y >= 0:
        outputiamge = os.path.join(
            outputiamge + "/" + filename + "_shift__" + str(int(round(abs(x), 3))) + "_" + str(int(round(y, 3))) + ".jpg")
        outputtxt = os.path.join(
            outputtxt + "/" + filename + "_shift__" + str(int(round(abs(x), 3))) + "_" + str(int(round(y, 3))) + extension)
    elif x < 0 and y < 0:
        outputiamge = os.path.join(
            outputiamge + "/" + filename + "_shift__" + str(int(round(abs(x), 3))) + "__" + str(int(round(abs(y), 3))) + ".jpg")
        outputtxt = os.path.join(
            outputtxt + "/" + filename + "_shift__" + str(int(round(abs(x), 3))) + "__" + str(int(round(abs(y), 3))) + extension)

    M = np.float32([[1, 0, x], [0, 1, y]])  # x为向左或右移动的像素值,正为向右负为向左; y为向上或者向下移动的像素值,正为向下负为向上
    shift_img = cv.warpAffine(img, M, (img.shape[1], img.shape[0]))
    cv.imwrite(outputiamge, shift_img,[int(cv.IMWRITE_JPEG_QUALITY), 50])
    # ---------------------- 平移boundingbox ----------------------
    save_txt = open(outputtxt, "w")
    f = open(inputtxt)
    for line in f.readlines():
        line = line.split(" ")
        x1 = float(line[0])
        y1 = float(line[1])
        x2 = float(line[2])
        y2 = float(line[3])
        x3 = float(line[4])
        y3 = float(line[5])
        x4 = float(line[6])
        y4 = float(line[7])
        category = str(line[8])
        dif = str(line[9])
        shift_str = str(int(round(x1 + x, 3))) + " " + str(int(round(y1 + y, 3))) + " " + str(int(round(x2 + x, 3))) + " " + str(int(round(y2 + y, 3))) + " " + str(int(round(x3 + x, 3))) + " " + str(int(round(y3 + y, 3))) + " " + str(int(round(x4 + x, 3))) + " " + str(int(round(y4 + y, 3))) + " " + category + " " + dif
        save_txt.write(shift_str)


# 裁剪图像
def crop_img_bboxes(img, inputtxt, outputiamge, outputtxt):
    # ---------------------- 裁剪图像 ----------------------
    w = img.shape[1]
    h = img.shape[0]
    x_min = 0  # 裁剪后的包含所有目标框的最小的框
    x_max = w
    y_min = 0
    y_max = h
    f = open(inputtxt)
    for line in f.readlines():
        line = line.split(" ")
        x1 = float(line[0])
        y1 = float(line[1])
        x2 = float(line[2])
        y2 = float(line[3])
        x3 = float(line[4])
        y3 = float(line[5])
        x4 = float(line[6])
        y4 = float(line[7])
        category = str(line[8])
        dif = str(line[9])

        x_min = min(x_min, x1, x2, x3, x4)
        y_min = min(y_min, y1, y2, y3, y4)
        x_max = max(x_max, x1, x2, x3, x4)
        y_max = max(y_max, y1, y2, y3, y4)

    d_to_left = x_min  # 包含所有目标框的最小框到左边的距离
    d_to_right = w - x_max  # 包含所有目标框的最小框到右边的距离
    d_to_top = y_min  # 包含所有目标框的最小框到顶端的距离
    d_to_bottom = h - y_max  # 包含所有目标框的最小框到底部的距离
    # 随机扩展这个最小框
    crop_x_min = int(x_min - random.uniform(0, d_to_left))
    crop_y_min = int(y_min - random.uniform(0, d_to_top))
    crop_x_max = int(x_max + random.uniform(0, d_to_right))
    crop_y_max = int(y_max + random.uniform(0, d_to_bottom))
    # 随机扩展这个最小框 , 防止别裁的太小
    # crop_x_min = int(x_min - random.uniform(d_to_left//2, d_to_left))
    # crop_y_min = int(y_min - random.uniform(d_to_top//2, d_to_top))
    # crop_x_max = int(x_max + random.uniform(d_to_right//2, d_to_right))
    # crop_y_max = int(y_max + random.uniform(d_to_bottom//2, d_to_bottom))
    # 确保不要越界
    crop_x_min = max(0, crop_x_min)
    crop_y_min = max(0, crop_y_min)
    crop_x_max = min(w, crop_x_max)
    crop_y_max = min(h, crop_y_max)
    crop_img = img[crop_y_min:crop_y_max, crop_x_min:crop_x_max]

    (filepath, tempfilename) = os.path.split(inputtxt)
    (filename, extension) = os.path.splitext(tempfilename)
    outputiamge = os.path.join(outputiamge + "/" + filename + "_crop_" + str(crop_x_min) + "_" +
                               str(crop_y_min) + "_" + str(crop_x_max) + "_" +
                               str(crop_y_max) + ".jpg")
    outputtxt = os.path.join(outputtxt + "/" + filename + "_crop_" + str(crop_x_min) + "_" +
                             str(crop_y_min) + "_" + str(crop_x_max) + "_" +
                             str(crop_y_max) + extension)
    cv.imwrite(outputiamge, crop_img,[int(cv.IMWRITE_JPEG_QUALITY), 50])
    # ---------------------- 裁剪boundingbox ----------------------
    # 裁剪后的boundingbox坐标计算
    save_txt = open(outputtxt, "w")
    f = open(inputtxt)
    for line in f.readlines():
        line = line.split(" ")
        x1 = float(line[0])
        y1 = float(line[1])
        x2 = float(line[2])
        y2 = float(line[3])
        x3 = float(line[4])
        y3 = float(line[5])
        x4 = float(line[6])
        y4 = float(line[7])
        category = str(line[8])
        dif = str(line[9])
        crop_str = str(int(round(x1 - crop_x_min, 3))) + " " + str(int(round(y1 - crop_y_min, 3))) + " " + str(int(round(x2 - crop_x_min, 3))) + " " + str(int(round(y2 - crop_y_min, 3))) + " " + str(int(round(x3 - crop_x_min, 3))) + " " + str(int(round(y3 - crop_y_min, 3))) + " " + str(int(round(x4 - crop_x_min, 3))) + " " + str(int(round(y4 - crop_y_min, 3))) + " " + category + " " + dif
        save_txt.write(crop_str)

if __name__ == '__main__':
    #inputiamge = "G://DOTA//org//train//new_images"
    #inputtxt = "G://DOTA//org//train//new_labelTxt"
    #outputiamge = "G://DOTA//train//aug//images"
    #outputtxt = "G://DOTA//train//aug//labels"
    
    inputiamge = "G://DOTA//train//object//large-vehicle//images"
    inputtxt = "G://DOTA//train//object//large-vehicle//labels"
    outputiamge = "G://DOTA//train//aug//large-vehicle//images"
    outputtxt = "G://DOTA//train//aug//large-vehicle//lables"
    
    #angle = [30, 60, 90, 120, 150, 180]
    angle = [60]
    #angle = [90]
    tempfilename = os.listdir(inputiamge)
    for file in tempfilename:
        (filename, extension) = os.path.splitext(file)
        input_image = os.path.join(inputiamge + "//" + file)
        input_txt = os.path.join(inputtxt + "//" + filename + ".txt")

        img = cv.imread(input_image)
        # 图像亮度变化 
        changeLight(img,input_txt,outputiamge,outputtxt)
        # 加高斯噪声
        gasuss_noise(img, input_txt, outputiamge, outputtxt, mean=0, var=0.001)
        # 改变图像对比度
        #ContrastAlgorithm(img, input_txt, outputiamge, outputtxt)
        # 图像旋转
        rotate_img_bbox(img, input_txt, outputiamge, outputtxt, angle)
        # 图像镜像
        #filp_pic_bboxes(img, input_txt, outputiamge, outputtxt)
        # 平移
        #shift_pic_bboxes(img, input_txt, outputiamge, outputtxt)
        # 剪切
        #crop_img_bboxes(img, input_txt, outputiamge, outputtxt)
    print("finished!")
# Out:
# finished!

# %% [markdown]
# # 降低图片质量

# %%
import cv2
import os
address = r"G:\DOTA\train\aug\images" # 存放原图片文件夹路径
list = os.listdir(address)
for i, file in enumerate(list):
    firstname = os.path.splitext(file)[0]
    typename = os.path.splitext(file)[1]
    os.rename("{}/{}".format(address, file), "{}/{}.jpg".format(address, i))
    newpath = address + "/"+"{}.jpg".format(i)

    #cv2.namedWindow("Image")  # 创建窗口
    img = cv2.imread(newpath)
    cv2.imshow("Image", img)
    changepic = r"G:\DOTA\train\aug\new_images\{}.jpg".format(i) # 修改完质量的图片存放路径
    cv2.imwrite(changepic, img, [int(cv2.IMWRITE_JPEG_QUALITY), 10])

cv2.waitKey(0)
cv2.destroyWindow("Image")  # 关闭窗口
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10132\1135672837.py in <module>
#       6     firstname = os.path.splitext(file)[0]
#       7     typename = os.path.splitext(file)[1]
# ----> 8     os.rename("{}/{}".format(address, file), "{}/{}.jpg".format(address, i))
#       9     newpath = address + "/"+"{}.jpg".format(i)
#      10
#
# KeyboardInterrupt:

# %%
#可视化yolo标签 yolo格式标签在原始图像中可视化显示

import numpy as np
import cv2
import torch

label_path = r'G:\DOTA\train\11\val\new_lables\P0003_0_0.txt'
image_path = r'G:\DOTA\train\11\val\images\P0003_0_0.jpg'

#坐标转换，原始存储的是YOLOv5格式
# Convert nx4 boxes from [x, y, w, h] normalized to [x1, y1, x2, y2] where xy1=top-left, xy2=bottom-right
def xywh2xyxy(x, w1, h1, img):
    #labels = ['person', 'car']
    labels = ['small-vehicle', 'large-vehicle', 'plane', 'storage-tank', 'ship', 'harbor', 'ground-track-field', 'soccer-ball-field', 'tennis-court', 'swimming-pool', 'baseball-diamond', 'roundabout', 'basketball-court', 'bridge', 'helicopter', 'container-crane']
    label, x, y, w, h = x
    print("原图宽高:\nw1={}\nh1={}".format(w1, h1))
    #边界框反归一化
    x_t = x*w1
    y_t = y*h1
    w_t = w*w1
    h_t = h*h1
    print("反归一化后输出：\n第一个:{}\t第二个:{}\t第三个:{}\t第四个:{}\t\n\n".format(x_t,y_t,w_t,h_t))

    #计算坐标
    top_left_x = x_t - w_t / 2
    top_left_y = y_t - h_t / 2
    bottom_right_x = x_t + w_t / 2
    bottom_right_y = y_t + h_t / 2
    print('标签:{}'.format(labels[int(label)]))
    print("左上x坐标:{}".format(top_left_x))
    print("左上y坐标:{}".format(top_left_y))
    print("右下x坐标:{}".format(bottom_right_x))
    print("右下y坐标:{}".format(bottom_right_y))

    # 绘图  rectangle()函数需要坐标为整数
    cv2.rectangle(img, (int(top_left_x), int(top_left_y)), (int(bottom_right_x), int(bottom_right_y)), (0, 255, 0), 2)
    cv2.imshow('show', img)
    cv2.imwrite('33.png',img)
    cv2.waitKey(0)  # 按键结束
    cv2.destroyAllWindows()


#读取 labels
with open(label_path, 'r') as f:
    lb = np.array([x.split() for x in f.read().strip().splitlines()], dtype=np.float32)  # labels
    print(lb)

# 读取图像文件
img = cv2.imread(str(image_path))
h, w = img.shape[:2]

for x in lb:
    # 反归一化并得到左上和右下坐标，画出矩形框
    xywh2xyxy(x, w, h, img)
# Out:
# [[0.         0.6503906  0.92626953 0.0546875  0.02636719]
#  [0.         0.5058594  0.49414062 0.05859375 0.02539062]
#  [0.         0.4946289  0.46533203 0.05761719 0.02441406]
#  [0.         0.64746094 0.25097656 0.0390625  0.1015625 ]
#  [0.         0.5913086  0.26464844 0.04199219 0.10742188]
#  [0.         0.56152344 0.27197266 0.03710938 0.09667969]
#  [0.         0.53222656 0.2758789  0.03515625 0.09863281]
#  [0.         0.48779297 0.28173828 0.04199219 0.10253906]
#  [0.         0.39257812 0.29736328 0.0390625  0.10058594]
#  [0.         0.3671875  0.3071289  0.0390625  0.10058594]
#  [0.         0.33496094 0.31054688 0.03320312 0.08789062]
#  [0.         0.30322266 0.30664062 0.03613281 0.08203125]
#  [0.         0.29882812 0.8183594  0.05664062 0.02929688]
#  [0.         0.5913086  0.49658203 0.06347656 0.02832031]
#  [0.         0.28955078 0.77783203 0.06152344 0.04785156]
#  [0.         0.28466797 0.7441406  0.05175781 0.0390625 ]
#  [0.         0.27978516 0.6743164  0.05566406 0.04199219]
#  [0.         0.3017578  0.62597656 0.05664062 0.04296875]
#  [0.         0.2529297  0.5991211  0.05273438 0.04394531]
#  [0.         0.2998047  0.5908203  0.05664062 0.04492188]
#  [0.         0.25097656 0.5649414  0.05273438 0.03808594]
#  [0.         0.2578125  0.47851562 0.09960938 0.06835938]
#  [0.         0.23095703 0.43066406 0.06347656 0.04296875]
#  [0.         0.22363281 0.3959961  0.05664062 0.04394531]
#  [0.         0.21240234 0.35742188 0.06152344 0.046875  ]
#  [0.         0.51953125 0.5258789  0.06054688 0.03027344]
#  [0.         0.5839844  0.5263672  0.05859375 0.01953125]
#  [0.         0.02490234 0.85253906 0.04199219 0.01757812]
#  [0.         0.02001953 0.8305664  0.03417969 0.01660156]
#  [0.         0.6171875  0.5527344  0.05859375 0.02148438]
#  [0.         0.8383789  0.85498047 0.02246094 0.05566406]
#  [0.         0.8076172  0.8286133  0.02734375 0.09472656]
#  [0.         0.78271484 0.84277344 0.02246094 0.06640625]
#  [0.         0.7529297  0.83984375 0.02148438 0.08984375]
#  [0.         0.71191406 0.85791016 0.02539062 0.05371094]
#  [0.         0.8408203  0.5942383  0.06640625 0.04394531]
#  [0.         0.796875   0.53564453 0.09570312 0.04980469]
#  [0.         0.5673828  0.57958984 0.09570312 0.02636719]
#  [0.         0.21875    0.29589844 0.06445312 0.05273438]]
# 原图宽高:
# w1=1024
# h1=1024
# 反归一化后输出：
# 第一个:666.0	第二个:948.5	第三个:56.0	第四个:27.0
#
#
# 标签:small-vehicle
# 左上x坐标:638.0
# 左上y坐标:935.0
# 右下x坐标:694.0
# 右下y坐标:962.0
# 原图宽高:
# w1=1024
# h1=1024
# 反归一化后输出：
# 第一个:518.0	第二个:506.0	第三个:60.0	第四个:26.0
#
#
# 标签:small-vehicle
# 左上x坐标:488.0
# 左上y坐标:493.0
# 右下x坐标:548.0
# 右下y坐标:519.0
# 原图宽高:
# w1=1024
# h1=1024
# 反归一化后输出：
# 第一个:506.5	第二个:476.5	第三个:59.0	第四个:25.0
#
#
# 标签:small-vehicle
# 左上x坐标:477.0
# 左上y坐标:464.0
# 右下x坐标:536.0
# 右下y坐标:489.0
# 原图宽高:
# w1=1024
# h1=1024
# 反归一化后输出：
# 第一个:663.0	第二个:257.0	第三个:40.0	第四个:104.0
#
#
# 标签:small-vehicle
# 左上x坐标:643.0
# 左上y坐标:205.0
# 右下x坐标:683.0
# 右下y坐标:309.0
# 原图宽高:
# w1=1024
# h1=1024
# 反归一化后输出：
# 第一个:605.5	第二个:271.0	第三个:43.0	第四个:110.0
#
#
# 标签:small-vehicle
# 左上x坐标:584.0
# 左上y坐标:216.0
# 右下x坐标:627.0
# 右下y坐标:326.0
# 原图宽高:
# w1=1024
# h1=1024
# 反归一化后输出：
# 第一个:575.0	第二个:278.5	第三个:38.0	第四个:99.0
#
#
# 标签:small-vehicle
# 左上x坐标:556.0
# 左上y坐标:229.0
# 右下x坐标:594.0
# 右下y坐标:328.0
# 原图宽高:
# w1=1024
# h1=1024
# 反归一化后输出：
# 第一个:545.0	第二个:282.5	第三个:36.0	第四个:101.0
#
#
# 标签:small-vehicle
# 左上x坐标:527.0
# 左上y坐标:232.0
# 右下x坐标:563.0
# 右下y坐标:333.0
# 原图宽高:
# w1=1024
# h1=1024
# 反归一化后输出：
# 第一个:499.5	第二个:288.5	第三个:43.0	第四个:105.0
#
#
# 标签:small-vehicle
# 左上x坐标:478.0
# 左上y坐标:236.0
# 右下x坐标:521.0
# 右下y坐标:341.0
# 原图宽高:
# w1=1024
# h1=1024
# 反归一化后输出：
# 第一个:402.0	第二个:304.5	第三个:40.0	第四个:103.0
#
#
# 标签:small-vehicle
# 左上x坐标:382.0
# 左上y坐标:253.0
# 右下x坐标:422.0
# 右下y坐标:356.0
# 原图宽高:
# w1=1024
# h1=1024
# 反归一化后输出：
# 第一个:376.0	第二个:314.5	第三个:40.0	第四个:103.0
#
#
# 标签:small-vehicle
# 左上x坐标:356.0
# 左上y坐标:263.0
# 右下x坐标:396.0
# 右下y坐标:366.0
# 原图宽高:
# w1=1024
# h1=1024
# 反归一化后输出：
# 第一个:343.0	第二个:318.0	第三个:34.0	第四个:90.0
#
#
# 标签:small-vehicle
# 左上x坐标:326.0
# 左上y坐标:273.0
# 右下x坐标:360.0
# 右下y坐标:363.0
# 原图宽高:
# w1=1024
# h1=1024
# 反归一化后输出：
# 第一个:310.5	第二个:314.0	第三个:37.0	第四个:84.0
#
#
# 标签:small-vehicle
# 左上x坐标:292.0
# 左上y坐标:272.0
# 右下x坐标:329.0
# 右下y坐标:356.0
# 原图宽高:
# w1=1024
# h1=1024
# 反归一化后输出：
# 第一个:306.0	第二个:838.0	第三个:58.0	第四个:30.0
#
#
# 标签:small-vehicle
# 左上x坐标:277.0
# 左上y坐标:823.0
# 右下x坐标:335.0
# 右下y坐标:853.0
# 原图宽高:
# w1=1024
# h1=1024
# 反归一化后输出：
# 第一个:605.5	第二个:508.5	第三个:65.0	第四个:29.0
#
#
# 标签:small-vehicle
# 左上x坐标:573.0
# 左上y坐标:494.0
# 右下x坐标:638.0
# 右下y坐标:523.0
# 原图宽高:
# w1=1024
# h1=1024
# 反归一化后输出：
# 第一个:296.5	第二个:796.5	第三个:63.0	第四个:49.0
#
#
# 标签:small-vehicle
# 左上x坐标:265.0
# 左上y坐标:772.0
# 右下x坐标:328.0
# 右下y坐标:821.0
# 原图宽高:
# w1=1024
# h1=1024
# 反归一化后输出：
# 第一个:291.5	第二个:762.0	第三个:53.0	第四个:40.0
#
#
# 标签:small-vehicle
# 左上x坐标:265.0
# 左上y坐标:742.0
# 右下x坐标:318.0
# 右下y坐标:782.0
# 原图宽高:
# w1=1024
# h1=1024
# 反归一化后输出：
# 第一个:286.5	第二个:690.5	第三个:57.0	第四个:43.0
#
#
# 标签:small-vehicle
# 左上x坐标:258.0
# 左上y坐标:669.0
# 右下x坐标:315.0
# 右下y坐标:712.0
# 原图宽高:
# w1=1024
# h1=1024
# 反归一化后输出：
# 第一个:309.0	第二个:641.0	第三个:58.0	第四个:44.0
#
#
# 标签:small-vehicle
# 左上x坐标:280.0
# 左上y坐标:619.0
# 右下x坐标:338.0
# 右下y坐标:663.0
# 原图宽高:
# w1=1024
# h1=1024
# 反归一化后输出：
# 第一个:259.0	第二个:613.5	第三个:54.0	第四个:45.0
#
#
# 标签:small-vehicle
# 左上x坐标:232.0
# 左上y坐标:591.0
# 右下x坐标:286.0
# 右下y坐标:636.0
# 原图宽高:
# w1=1024
# h1=1024
# 反归一化后输出：
# 第一个:307.0	第二个:605.0	第三个:58.0	第四个:46.0
#
#
# 标签:small-vehicle
# 左上x坐标:278.0
# 左上y坐标:582.0
# 右下x坐标:336.0
# 右下y坐标:628.0
# 原图宽高:
# w1=1024
# h1=1024
# 反归一化后输出：
# 第一个:257.0	第二个:578.5	第三个:54.0	第四个:39.0
#
#
# 标签:small-vehicle
# 左上x坐标:230.0
# 左上y坐标:559.0
# 右下x坐标:284.0
# 右下y坐标:598.0
# 原图宽高:
# w1=1024
# h1=1024
# 反归一化后输出：
# 第一个:264.0	第二个:490.0	第三个:102.0	第四个:70.0
#
#
# 标签:small-vehicle
# 左上x坐标:213.0
# 左上y坐标:455.0
# 右下x坐标:315.0
# 右下y坐标:525.0
# 原图宽高:
# w1=1024
# h1=1024
# 反归一化后输出：
# 第一个:236.5	第二个:441.0	第三个:65.0	第四个:44.0
#
#
# 标签:small-vehicle
# 左上x坐标:204.0
# 左上y坐标:419.0
# 右下x坐标:269.0
# 右下y坐标:463.0
# 原图宽高:
# w1=1024
# h1=1024
# 反归一化后输出：
# 第一个:229.0	第二个:405.5	第三个:58.0	第四个:45.0
#
#
# 标签:small-vehicle
# 左上x坐标:200.0
# 左上y坐标:383.0
# 右下x坐标:258.0
# 右下y坐标:428.0
# 原图宽高:
# w1=1024
# h1=1024
# 反归一化后输出：
# 第一个:217.5	第二个:366.0	第三个:63.0	第四个:48.0
#
#
# 标签:small-vehicle
# 左上x坐标:186.0
# 左上y坐标:342.0
# 右下x坐标:249.0
# 右下y坐标:390.0
# 原图宽高:
# w1=1024
# h1=1024
# 反归一化后输出：
# 第一个:532.0	第二个:538.5	第三个:62.0	第四个:31.0
#
#
# 标签:small-vehicle
# 左上x坐标:501.0
# 左上y坐标:523.0
# 右下x坐标:563.0
# 右下y坐标:554.0
# 原图宽高:
# w1=1024
# h1=1024
# 反归一化后输出：
# 第一个:598.0	第二个:539.0	第三个:60.0	第四个:20.0
#
#
# 标签:small-vehicle
# 左上x坐标:568.0
# 左上y坐标:529.0
# 右下x坐标:628.0
# 右下y坐标:549.0
# 原图宽高:
# w1=1024
# h1=1024
# 反归一化后输出：
# 第一个:25.5	第二个:873.0	第三个:43.0	第四个:18.0
#
#
# 标签:small-vehicle
# 左上x坐标:4.0
# 左上y坐标:864.0
# 右下x坐标:47.0
# 右下y坐标:882.0
# 原图宽高:
# w1=1024
# h1=1024
# 反归一化后输出：
# 第一个:20.5	第二个:850.5	第三个:35.0	第四个:17.0
#
#
# 标签:small-vehicle
# 左上x坐标:3.0
# 左上y坐标:842.0
# 右下x坐标:38.0
# 右下y坐标:859.0
# 原图宽高:
# w1=1024
# h1=1024
# 反归一化后输出：
# 第一个:632.0	第二个:566.0	第三个:60.0	第四个:22.0
#
#
# 标签:small-vehicle
# 左上x坐标:602.0
# 左上y坐标:555.0
# 右下x坐标:662.0
# 右下y坐标:577.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11184\3256554564.py in <module>
#      52 for x in lb:
#      53     # 反归一化并得到左上和右下坐标，画出矩形框
# ---> 54     xywh2xyxy(x, w, h, img)
#
# ~\AppData\Local\Temp\ipykernel_11184\3256554564.py in xywh2xyxy(x, w1, h1, img)
#      37     cv2.imshow('show', img)
#      38     cv2.imwrite('33.png',img)
# ---> 39     cv2.waitKey(0)  # 按键结束
#      40     cv2.destroyAllWindows()
#      41
#
# KeyboardInterrupt:

# %%
x = ['large-vehicle','plane','ship','harbor','tennis-court','baseball-diamond','basketball-court','helicopter']
y = [1637,1840,1847,1650,692,321,271,111]
y1 = [32575,12594,54528,9971,4113,648,777,1018]

import matplotlib.pyplot as plt 
plt.rcParams['font.sans-serif'] = 'SimHei'
plt.rcParams['axes.unicode_minus'] = False

p = plt.figure(figsize=(16,6))
ax1 = p.add_subplot(1,2,1)

plt.xlabel('类别',fontsize=15)
plt.ylabel('数量',fontsize=15)
plt.title('不同类别图像数量图',fontsize=16)
plt.xticks(fontsize=12,rotation=60)

for i in range(len(y)):
    plt.bar(x[i],y[i])
    plt.text(x[i],y[i],y[i],va='bottom',ha='center',fontsize=10)
    
ax2 = p.add_subplot(1,2,2)
plt.xlabel('类别',fontsize=12)
plt.ylabel('数量',fontsize=12)
plt.title('不同类别标签数量图',fontsize=20)
plt.xticks(fontsize=12,rotation=60)

for i in range(len(y)):
    plt.bar(x[i],y1[i])
    plt.text(x[i],y1[i],y1[i],va='bottom',ha='center',fontsize=10)

# %%
x = ['large-vehicle','plane','ship','harbor','tennis-court','baseball-diamond','basketball-court','helicopter']
y = [380,197,326,339,302,102,111,30]
y1 = [16969,7971,28068,5983,2367,415,515,630]

import matplotlib.pyplot as plt 
plt.rcParams['font.sans-serif'] = 'SimHei'
plt.rcParams['axes.unicode_minus'] = False

p = plt.figure(figsize=(16,6))
ax1 = p.add_subplot(1,2,1)

plt.xlabel('类别',fontsize=12)
plt.ylabel('数量',fontsize=12)
plt.title('不同类别图像数量图',fontsize=16)
plt.xticks(fontsize=12,rotation=60)
color = ['#D5BA82','#B36A6F','#A1D0C7','#508AB2','#F0BB41','#508AB2','#98A1B1','#934833']

for i in range(len(y)):
    plt.bar(x[i],y[i],color=color[i])
    plt.text(x[i],y[i],y[i],va='bottom',ha='center',fontsize=10)
    
ax2 = p.add_subplot(1,2,2)
plt.xlabel('类别',fontsize=12)
plt.ylabel('数量',fontsize=12)
plt.title('不同类别标签数量图',fontsize=16)
plt.xticks(fontsize=12,rotation=60)

for i in range(len(y)):
    plt.bar(x[i],y1[i],color=color[i])
    plt.text(x[i],y1[i],y1[i],va='bottom',ha='center',fontsize=10)

# %%
import matplotlib; matplotlib.use('TkAgg')
from pylab import *
mpl.rcParams['font.sans-serif'] = ['SimHei']
mpl.rcParams['axes.unicode_minus'] = False
zhfont1 = matplotlib.font_manager.FontProperties(fname='C:\Windows\Fonts\simsun.ttc')



name_list=['large-vehicle','plane','ship','harbor','tennis-court','baseball-diamond','basketball-court','helicopter']
num_list = [1637,1840,1847,1650,692,321,271,111]#分解
num_list1 = [32575,12594,54528,9971,4113,648,777,1018]#真实
x = list(range(len(num_list)))
width=0.3;#柱子的宽度
index=np.arange(len(name_list));
plt.bar(index,num_list,width,color='steelblue',tick_label = name_list,label='图像数量')
plt.bar(index+width,num_list1,width,color='red',hatch='\\',label='标签数量')
plt.legend(['分解能耗','真实能耗'],prop=zhfont1,labelspacing=1)

for a,b in zip(index,num_list):   #柱子上的数字显示
 plt.text(a,b,'%.2f'%b,ha='center',va='bottom',fontsize=7);
for a,b in zip(index+width,num_list1):
 plt.text(a,b,'%.2f'%b,ha='center',va='bottom',fontsize=7);

plt.title('26号用户2015/7/1 0:00:00到2015/7/12 23:00:00 电器能耗图')
plt.ylabel('kWh')
plt.legend()
plt.show()

# %% [markdown]
# # 绘制长宽散点图

# %%
import time
import matplotlib.image as mping
import os
import matplotlib.pyplot as plt

#获取单个图片的大小
def get_Image_Size(image_Path):
    #print("获取图片尺寸大小："+ image_Path)
    try:
        lena = mping.imread(image_Path)
    except:
        time.sleep(0.5)
        print("读图出错，重读")
        getPngSize(image_Path)
    size = tuple(lena.shape)
    #print(size)
    return size[1],size[0]

#遍历目标文件夹下图片的大小，保存到list中
def get_dir_list(image_path):
    w_list = []
    h_list = []
    files = os.listdir(image_path)
    for i in files:
        if i.endswith('.png'):
            w,h = get_Image_Size(image_path + i)
            #print(w,h)
            w_list.append(w)
            h_list.append(h)
    return w_list,h_list

#画散点图
def plot_pic(w_list,h_list):
    fig = plt.figure()
    ax1 = fig.add_subplot(1, 1, 1)
    ax1.set_title('原图大小分布图')
    ax1.scatter(w_list, h_list, s=5, c='k', marker='.')
    plt.show()

if __name__ == '__main__':
    image_path = r"G:\\DOTA\\org\\train\\images\\"  #目标文件夹，也就是图片存放的目录
    w_list,h_list = get_dir_list(image_path)
    plot_pic(w_list,h_list)

# %%
fig = plt.figure()
ax1 = fig.add_subplot(1, 1, 1)
ax1.set_title('原图大小分布图',fontsize=12)
ax1.scatter(w_list, h_list, s=5, c='RoyalBlue', marker='.')
plt.xlabel('原图宽度',fontsize=10)
plt.ylabel('原图高度',fontsize=10)
plt.show()

# %%
import pandas as pd 
data = pd.read_csv(r'G:/DOTA/data_org.csv',encoding='GBK')
data.head()

import matplotlib.pyplot as plt 
plt.rcParams['font.sans-serif'] = 'SimHei'
plt.rcParams['axes.unicode_minus'] = False

x = data['长']
y = data['宽']

fig = plt.figure()
ax1 = fig.add_subplot(1, 1, 1)
ax1.set_title('box大小分布散点图',fontsize=12)
ax1.scatter(x, y, s=5, c='RoyalBlue', marker='.')
plt.xlabel('box宽度',fontsize=10)
plt.ylabel('box高度',fontsize=10)
plt.show()

# %%
x = ['large-vehicle','plane','ship','harbor','tennis-court','baseball-diamond','basketball-court','helicopter']
y = [5942,5512,5537,4816,2712,4118,3232,1438]
y1 = [1637,1839,1847,1650,692,321,271,111]

import matplotlib.pyplot as plt 
plt.rcParams['font.sans-serif'] = 'SimHei'
plt.rcParams['axes.unicode_minus'] = False

plt.xlabel('类别',fontsize=10)
plt.ylabel('数量',fontsize=10)
plt.title('不同类别图像数量图',fontsize=12)
plt.xticks(fontsize=10,rotation=60)
color = ['#D5BA82','#B36A6F','#A1D0C7','#508AB2','#F0BB41','#508AB2','#98A1B1','#934833']

for i in range(len(x)):
    plt.bar(x[i],y1[i],color=color[i])
    plt.text(x[i],y1[i],y1[i],va='bottom',ha='center',fontsize=10)
